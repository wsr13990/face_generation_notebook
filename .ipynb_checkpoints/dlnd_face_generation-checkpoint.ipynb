# %% [markdown]
# # Face Generation
# In this project, you'll use generative adversarial networks to generate new images of faces.
# ### Get the Data
# You'll be using two datasets in this project:
# - MNIST
# - CelebA
#
# Since the celebA dataset is complex and you're doing GANs in a project for the first time, we want you to test your neural network on MNIST before CelebA.  Running the GANs on MNIST will allow you to see how well your model trains sooner.
#
# If you're using [FloydHub](https://www.floydhub.com/), set `data_dir` to "/input" and use the [FloydHub data ID](http://docs.floydhub.com/home/using_datasets/) "R5KrjnANiKVhLWAkpXhNBe".

# %%
data_dir = './data'

# FloydHub - Use with data ID "R5KrjnANiKVhLWAkpXhNBe"
#data_dir = '/input'


"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import helper

helper.download_extract('mnist', data_dir)
helper.download_extract('celeba', data_dir)
# Out:
# Found mnist Data
# Found celeba Data

# %% [markdown]
# ## Explore the Data
# ### MNIST
# As you're aware, the [MNIST](http://yann.lecun.com/exdb/mnist/) dataset contains images of handwritten digits. You can view the first number of examples by changing `show_n_images`.

# %%
show_n_images = 25

"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# %matplotlib inline
import os
from glob import glob
from matplotlib import pyplot

mnist_images = helper.get_batch(glob(os.path.join(data_dir, 'mnist/*.jpg'))[:show_n_images], 28, 28, 'L')
pyplot.imshow(helper.images_square_grid(mnist_images, 'L'), cmap='gray')

# %% [markdown]
# ### CelebA
# The [CelebFaces Attributes Dataset (CelebA)](http://mmlab.ie.cuhk.edu.hk/projects/CelebA.html) dataset contains over 200,000 celebrity images with annotations.  Since you're going to be generating faces, you won't need the annotations.  You can view the first number of examples by changing `show_n_images`.

# %%
show_n_images = 25

"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
mnist_images = helper.get_batch(glob(os.path.join(data_dir, 'img_align_celeba/*.jpg'))[:show_n_images], 28, 28, 'RGB')
pyplot.imshow(helper.images_square_grid(mnist_images, 'RGB'))

# %% [markdown]
# ## Preprocess the Data
# Since the project's main focus is on building the GANs, we'll preprocess the data for you.  The values of the MNIST and CelebA dataset will be in the range of -0.5 to 0.5 of 28x28 dimensional images.  The CelebA images will be cropped to remove parts of the image that don't include a face, then resized down to 28x28.
#
# The MNIST images are black and white images with a single [color channel](https://en.wikipedia.org/wiki/Channel_(digital_image%29) while the CelebA images have [3 color channels (RGB color channel)](https://en.wikipedia.org/wiki/Channel_(digital_image%29#RGB_Images).
# ## Build the Neural Network
# You'll build the components necessary to build a GANs by implementing the following functions below:
# - `model_inputs`
# - `discriminator`
# - `generator`
# - `model_loss`
# - `model_opt`
# - `train`
#
# ### Check the Version of TensorFlow and Access to GPU
# This will check to make sure you have the correct version of TensorFlow and access to a GPU

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
from distutils.version import LooseVersion
import warnings
import tensorflow as tf

# Check TensorFlow Version
assert LooseVersion(tf.__version__) >= LooseVersion('1.0'), 'Please use TensorFlow version 1.0 or newer.  You are using {}'.format(tf.__version__)
print('TensorFlow Version: {}'.format(tf.__version__))

# Check for a GPU
if not tf.test.gpu_device_name():
    warnings.warn('No GPU found. Please use a GPU to train your neural network.')
else:
    print('Default GPU Device: {}'.format(tf.test.gpu_device_name()))
# Out:
# TensorFlow Version: 1.4.0
# Default GPU Device: /device:GPU:0

# %% [markdown]
# ### Input
# Implement the `model_inputs` function to create TF Placeholders for the Neural Network. It should create the following placeholders:
# - Real input images placeholder with rank 4 using `image_width`, `image_height`, and `image_channels`.
# - Z input placeholder with rank 2 using `z_dim`.
# - Learning rate placeholder with rank 0.
#
# Return the placeholders in the following the tuple (tensor of real input images, tensor of z data)

# %%
import problem_unittests as tests
tf.reset_default_graph()
def model_inputs(image_width, image_height, image_channels, z_dim):
    """
    Create the model inputs
    :param image_width: The input image width
    :param image_height: The input image height
    :param image_channels: The number of image channels
    :param z_dim: The dimension of Z
    :return: Tuple of (tensor of real input images, tensor of z data, learning rate)
    """
    # TODO: Implement Function
    input_real = tf.placeholder(dtype=tf.float32,shape=(None,image_width,image_height,image_channels),name='input_real')
    input_z = tf.placeholder(dtype=tf.float32,shape=(None,z_dim),name='input_z')
    learning_rate = tf.placeholder(dtype=tf.float32,shape=None,name='learning_rate')
    
    return (input_real,input_z,learning_rate)


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_model_inputs(model_inputs)
# Out:
# Tests Passed

# %% [markdown]
# ### Discriminator
# Implement `discriminator` to create a discriminator neural network that discriminates on `images`.  This function should be able to reuse the variables in the neural network.  Use [`tf.variable_scope`](https://www.tensorflow.org/api_docs/python/tf/variable_scope) with a scope name of "discriminator" to allow the variables to be reused.  The function should return a tuple of (tensor output of the discriminator, tensor logits of the discriminator).

# %%
def discriminator(images, reuse=False):
    """
    Create the discriminator network
    :param images: Tensor of input image(s)
    :param reuse: Boolean if the weights should be reused
    :return: Tuple of (tensor output of the discriminator, tensor logits of the discriminator)
    """
    # TODO: Implement Function
    with tf.variable_scope('discriminator',reuse=reuse):
        alpha = 0.2
        #28x28x3
        x1 = tf.layers.conv2d(images,64,5,strides=2,padding='same')
        x1 = tf.maximum(x1*alpha,x1)
        #14x14x128
        
        x2 = tf.layers.conv2d(x1,128,5,strides=2,padding='same')
        x2 = tf.layers.batch_normalization(x2,training=True)
        x2 = tf.maximum(x2*alpha,x2)
        #7x7x256
        
        x3 = tf.layers.conv2d(x2,256,5,strides=2,padding='same')
        x3 = tf.layers.batch_normalization(x3,training=True)
        x3 = tf.maximum(x3*alpha,x3)
        #4x4x512
        
        flat = tf.reshape(x3,(-1,4*4*256))
        logits = tf.layers.dense(flat,1)
        output = tf.sigmoid(logits)
    return (output,logits)


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_discriminator(discriminator, tf)
# Out:
# Tests Passed

# %% [markdown]
# ### Generator
# Implement `generator` to generate an image using `z`. This function should be able to reuse the variables in the neural network.  Use [`tf.variable_scope`](https://www.tensorflow.org/api_docs/python/tf/variable_scope) with a scope name of "generator" to allow the variables to be reused. The function should return the generated 28 x 28 x `out_channel_dim` images.

# %%
def generator(z, out_channel_dim, is_train=True):
    """
    Create the generator network
    :param z: Input z
    :param out_channel_dim: The number of channels in the output image
    :param is_train: Boolean if generator is being used for training
    :return: The tensor output of the generator
    """
    with tf.variable_scope('generator',reuse=not is_train):
        # TODO: Implement Function
        alpha = 0.2
        x1 = tf.layers.dense(z,4*4*512)
        x1 = tf.reshape(x1,(-1,4,4,512))
        x1 = tf.layers.batch_normalization(x1,training=is_train)
        x1 = tf.maximum(x1*alpha,x1)
        #4x4X512
        
        x2 = tf.layers.conv2d_transpose(x1,256,4,strides=1,padding='valid')
        x2 = tf.layers.batch_normalization(x2,training=is_train)
        x2 = tf.maximum(x2*alpha,x2)
        #7x7x256
        
        x3 = tf.layers.conv2d_transpose(x2,128,5,strides=2,padding='same')
        x3 = tf.layers.batch_normalization(x3,training=is_train)
        x3 = tf.maximum(x3*alpha,x3)
        #14x14x128

        logits = tf.layers.conv2d_transpose(x3,filters=out_channel_dim,kernel_size=5,strides=2,padding='same')
        out = tf.tanh(logits)
        #28x28x3
        return out


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_generator(generator, tf)
# Out:
# Tests Passed

# %% [markdown]
# ### Loss
# Implement `model_loss` to build the GANs for training and calculate the loss.  The function should return a tuple of (discriminator loss, generator loss).  Use the following functions you implemented:
# - `discriminator(images, reuse=False)`
# - `generator(z, out_channel_dim, is_train=True)`

# %%
def model_loss(input_real, input_z, out_channel_dim):
    """
    Get the loss for the discriminator and generator
    :param input_real: Images from the real dataset
    :param input_z: Z input
    :param out_channel_dim: The number of channels in the output image
    :return: A tuple of (discriminator loss, generator loss)
    """
    # TODO: Implement Function
    smooth = 0.1
    g_model = generator(input_z,out_channel_dim)
    d_model_real, d_logit_real = discriminator(input_real)
    d_model_fake, d_logit_fake = discriminator(g_model,reuse=True)
    
    d_loss_real = tf.reduce_mean(tf.nn.sigmoid_cross_entropy_with_logits(logits=d_logit_real,\
                                                                         labels=tf.ones_like(d_model_real)*(1-smooth)))
    d_loss_fake = tf.reduce_mean(tf.nn.sigmoid_cross_entropy_with_logits(logits=d_logit_fake,\
                                                                         labels=tf.zeros_like(d_model_fake)))
    g_loss = tf.reduce_mean(tf.nn.sigmoid_cross_entropy_with_logits(logits=d_logit_fake,\
                                                     labels=tf.ones_like(d_model_fake)))
    d_loss = d_loss_real+d_loss_fake
    
    return (d_loss,g_loss)


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_model_loss(model_loss)
# Out:
# Tests Passed

# %% [markdown]
# ### Optimization
# Implement `model_opt` to create the optimization operations for the GANs. Use [`tf.trainable_variables`](https://www.tensorflow.org/api_docs/python/tf/trainable_variables) to get all the trainable variables.  Filter the variables with names that are in the discriminator and generator scope names.  The function should return a tuple of (discriminator training operation, generator training operation).

# %%
def model_opt(d_loss, g_loss, learning_rate, beta1):
    """
    Get optimization operations
    :param d_loss: Discriminator loss Tensor
    :param g_loss: Generator loss Tensor
    :param learning_rate: Learning Rate Placeholder
    :param beta1: The exponential decay rate for the 1st moment in the optimizer
    :return: A tuple of (discriminator training operation, generator training operation)
    """
    # TODO: Implement Function
    t_var = tf.trainable_variables()
    g_var = [var for var in t_var if var.name.startswith('generator')]
    d_var = [var for var in t_var if var.name.startswith('discriminator')]
    
    d_train_opt = tf.train.AdamOptimizer(learning_rate,beta1=beta1).minimize(d_loss,var_list=d_var)
    g_train_opt = tf.train.AdamOptimizer(learning_rate,beta1=beta1).minimize(g_loss,var_list=g_var)
    return (d_train_opt,g_train_opt)


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_model_opt(model_opt, tf)
# Out:
# Tests Passed

# %% [markdown]
# ## Neural Network Training
# ### Show Output
# Use this function to show the current output of the generator during training. It will help you determine how well the GANs is training.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import numpy as np

def show_generator_output(sess, n_images, input_z, out_channel_dim, image_mode):
    """
    Show example output for the generator
    :param sess: TensorFlow session
    :param n_images: Number of Images to display
    :param input_z: Input Z Tensor
    :param out_channel_dim: The number of channels in the output image
    :param image_mode: The mode to use for images ("RGB" or "L")
    """
    cmap = None if image_mode == 'RGB' else 'gray'
    z_dim = input_z.get_shape().as_list()[-1]
    example_z = np.random.uniform(-1, 1, size=[n_images, z_dim])

    samples = sess.run(
        generator(input_z, out_channel_dim, False),
        feed_dict={input_z: example_z})

    images_grid = helper.images_square_grid(samples, image_mode)
    pyplot.imshow(images_grid, cmap=cmap)
    pyplot.show()

# %% [markdown]
# ### Train
# Implement `train` to build and train the GANs.  Use the following functions you implemented:
# - `model_inputs(image_width, image_height, image_channels, z_dim)`
# - `model_loss(input_real, input_z, out_channel_dim)`
# - `model_opt(d_loss, g_loss, learning_rate, beta1)`
#
# Use the `show_generator_output` to show `generator` output while you train. Running `show_generator_output` for every batch will drastically increase training time and increase the size of the notebook.  It's recommended to print the `generator` output every 100 batches.

# %%
def train(epoch_count, batch_size, z_dim, learning_rate, beta1, get_batches, data_shape, data_image_mode):
    """
    Train the GAN
    :param epoch_count: Number of epochs
    :param batch_size: Batch Size
    :param z_dim: Z dimension
    :param learning_rate: Learning Rate
    :param beta1: The exponential decay rate for the 1st moment in the optimizer
    :param get_batches: Function to get batches
    :param data_shape: Shape of the data
    :param data_image_mode: The image mode to use for images ("RGB" or "L")
    """
    # TODO: Build Model
    import numpy as np
    input_real,input_z,learning_rate_ = model_inputs(data_shape[1],data_shape[2],data_shape[3],z_dim)
    d_loss, g_loss = model_loss(input_real,input_z,data_shape[3])
    d_opt, g_opt = model_opt(d_loss,g_loss,learning_rate_,beta1)
    
    saver = tf.train.Saver()
    sample,losses = [],[]
    steps = 0
        
    with tf.Session() as sess:
        sess.run(tf.global_variables_initializer())
        for epoch_i in range(epoch_count):
            for batch_images in get_batches(batch_size):
                # TODO: Train Model
                steps += 1
                batch_images = batch_images*2
                batch_z = np.random.uniform(-1,1,size=[batch_size,z_dim])
                
                _ = sess.run(d_opt,feed_dict={input_real:batch_images,input_z:batch_z,learning_rate_:learning_rate})
                _ = sess.run(g_opt,feed_dict={input_z:batch_z,input_real:batch_images,learning_rate_:learning_rate})
                _ = sess.run(g_opt,feed_dict={input_z:batch_z,input_real:batch_images,learning_rate_:learning_rate})
                
                if steps % 10 == 0:
                    train_loss_d = d_loss.eval({input_z:batch_z,input_real:batch_images})
                    train_loss_g = g_loss.eval({input_z:batch_z})
                
                    print("Epoch {}/{}...".format(epoch_i+1,epoch_count),
                          "Step {}".format(steps),
                          "Discriminator Loss: {:.4f}...".format(train_loss_d),
                          "Generator Loss: {:.4f}".format(train_loss_g))
                    # Save losses to view after training
                    losses.append((train_loss_d, train_loss_g))
                
                if steps % 100 == 0:
                    show_generator_output(sess=sess,n_images=25,input_z=input_z,out_channel_dim=data_shape[3],image_mode=data_image_mode)
                    saver.save(sess, './checkpoints/generator.ckpt')
    return losses

# %% [markdown]
# ### MNIST
# Test your GANs architecture on MNIST.  After 2 epochs, the GANs should be able to generate images that look like handwritten digits.  Make sure the loss of the generator is lower than the loss of the discriminator or close to 0.

# %%
batch_size = 32
z_dim = 50
learning_rate = 0.002
beta1 = 0.3
#tf.reset_default_graph()

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
epochs = 2

mnist_dataset = helper.Dataset('mnist', glob(os.path.join(data_dir, 'mnist/*.jpg')))
with tf.Graph().as_default():
    train(epochs, batch_size, z_dim, learning_rate, beta1, mnist_dataset.get_batches,
          mnist_dataset.shape, mnist_dataset.image_mode)
# Out:
# Epoch 1/2... Step 10 Discriminator Loss: 1.0248... Generator Loss: 1.3316
# Epoch 1/2... Step 20 Discriminator Loss: 0.6519... Generator Loss: 5.2033
# Epoch 1/2... Step 30 Discriminator Loss: 0.6035... Generator Loss: 11.3079
# Epoch 1/2... Step 40 Discriminator Loss: 0.4363... Generator Loss: 4.7861
# Epoch 1/2... Step 50 Discriminator Loss: 0.4893... Generator Loss: 2.3846
# Epoch 1/2... Step 60 Discriminator Loss: 0.4833... Generator Loss: 2.9803
# Epoch 1/2... Step 70 Discriminator Loss: 0.9251... Generator Loss: 1.5962
# Epoch 1/2... Step 80 Discriminator Loss: 0.5153... Generator Loss: 3.3257
# Epoch 1/2... Step 90 Discriminator Loss: 0.6924... Generator Loss: 1.6656
# Epoch 1/2... Step 100 Discriminator Loss: 0.5881... Generator Loss: 3.9309
# Epoch 1/2... Step 110 Discriminator Loss: 5.3509... Generator Loss: 9.2218
# Epoch 1/2... Step 120 Discriminator Loss: 1.2050... Generator Loss: 0.9987
# Epoch 1/2... Step 130 Discriminator Loss: 1.0885... Generator Loss: 1.2748
# Epoch 1/2... Step 140 Discriminator Loss: 1.1735... Generator Loss: 2.0781
# Epoch 1/2... Step 150 Discriminator Loss: 1.8884... Generator Loss: 2.4368
# Epoch 1/2... Step 160 Discriminator Loss: 1.5235... Generator Loss: 0.4961
# Epoch 1/2... Step 170 Discriminator Loss: 2.3394... Generator Loss: 0.1818
# Epoch 1/2... Step 180 Discriminator Loss: 1.2206... Generator Loss: 0.6713
# Epoch 1/2... Step 190 Discriminator Loss: 0.9954... Generator Loss: 1.9979
# Epoch 1/2... Step 200 Discriminator Loss: 1.2857... Generator Loss: 0.9377
# Epoch 1/2... Step 210 Discriminator Loss: 1.1252... Generator Loss: 2.6354
# Epoch 1/2... Step 220 Discriminator Loss: 0.7063... Generator Loss: 2.1247
# Epoch 1/2... Step 230 Discriminator Loss: 0.8867... Generator Loss: 1.3447
# Epoch 1/2... Step 240 Discriminator Loss: 1.1367... Generator Loss: 0.8469
# Epoch 1/2... Step 250 Discriminator Loss: 1.0179... Generator Loss: 1.0271
# Epoch 1/2... Step 260 Discriminator Loss: 1.9011... Generator Loss: 0.3284
# Epoch 1/2... Step 270 Discriminator Loss: 0.8262... Generator Loss: 1.3363
# Epoch 1/2... Step 280 Discriminator Loss: 1.4611... Generator Loss: 0.5484
# Epoch 1/2... Step 290 Discriminator Loss: 1.1595... Generator Loss: 0.8659
# Epoch 1/2... Step 300 Discriminator Loss: 1.0030... Generator Loss: 2.2642
# Epoch 1/2... Step 310 Discriminator Loss: 0.6213... Generator Loss: 1.9115
# Epoch 1/2... Step 320 Discriminator Loss: 2.8994... Generator Loss: 4.6037
# Epoch 1/2... Step 330 Discriminator Loss: 1.0559... Generator Loss: 0.9654
# Epoch 1/2... Step 340 Discriminator Loss: 1.5845... Generator Loss: 0.4639
# Epoch 1/2... Step 350 Discriminator Loss: 1.4763... Generator Loss: 0.4812
# Epoch 1/2... Step 360 Discriminator Loss: 1.2216... Generator Loss: 1.1068
# Epoch 1/2... Step 370 Discriminator Loss: 1.1752... Generator Loss: 0.9102
# Epoch 1/2... Step 380 Discriminator Loss: 1.0484... Generator Loss: 1.0389
# Epoch 1/2... Step 390 Discriminator Loss: 2.1421... Generator Loss: 4.1042
# Epoch 1/2... Step 400 Discriminator Loss: 1.2216... Generator Loss: 0.7780
# Epoch 1/2... Step 410 Discriminator Loss: 1.2645... Generator Loss: 0.9970
# Epoch 1/2... Step 420 Discriminator Loss: 0.7817... Generator Loss: 1.3827
# Epoch 1/2... Step 430 Discriminator Loss: 0.8280... Generator Loss: 2.5067
# Epoch 1/2... Step 440 Discriminator Loss: 1.1233... Generator Loss: 0.8360
# Epoch 1/2... Step 450 Discriminator Loss: 1.0313... Generator Loss: 0.8793
# Epoch 1/2... Step 460 Discriminator Loss: 1.4325... Generator Loss: 0.6000
# Epoch 1/2... Step 470 Discriminator Loss: 1.4340... Generator Loss: 0.6306
# Epoch 1/2... Step 480 Discriminator Loss: 1.0683... Generator Loss: 0.9621
# Epoch 1/2... Step 490 Discriminator Loss: 1.1513... Generator Loss: 1.1276
# Epoch 1/2... Step 500 Discriminator Loss: 1.5482... Generator Loss: 0.5518
# Epoch 1/2... Step 510 Discriminator Loss: 0.9976... Generator Loss: 1.4860
# Epoch 1/2... Step 520 Discriminator Loss: 0.9974... Generator Loss: 1.2303
# Epoch 1/2... Step 530 Discriminator Loss: 1.1009... Generator Loss: 0.7807
# Epoch 1/2... Step 540 Discriminator Loss: 1.1844... Generator Loss: 1.7051
# Epoch 1/2... Step 550 Discriminator Loss: 1.1659... Generator Loss: 0.9468
# Epoch 1/2... Step 560 Discriminator Loss: 1.2060... Generator Loss: 1.3511
# Epoch 1/2... Step 570 Discriminator Loss: 1.1998... Generator Loss: 0.7965
# Epoch 1/2... Step 580 Discriminator Loss: 1.2091... Generator Loss: 0.7391
# Epoch 1/2... Step 590 Discriminator Loss: 1.0544... Generator Loss: 1.6399
# Epoch 1/2... Step 600 Discriminator Loss: 0.9150... Generator Loss: 1.2708
# Epoch 1/2... Step 610 Discriminator Loss: 1.5438... Generator Loss: 2.7130
# Epoch 1/2... Step 620 Discriminator Loss: 1.2127... Generator Loss: 0.7232
# Epoch 1/2... Step 630 Discriminator Loss: 1.2208... Generator Loss: 0.7476
# Epoch 1/2... Step 640 Discriminator Loss: 1.0198... Generator Loss: 1.9968
# Epoch 1/2... Step 650 Discriminator Loss: 1.3304... Generator Loss: 0.7077
# Epoch 1/2... Step 660 Discriminator Loss: 1.0317... Generator Loss: 1.8336
# Epoch 1/2... Step 670 Discriminator Loss: 1.8517... Generator Loss: 3.2970
# Epoch 1/2... Step 680 Discriminator Loss: 0.9410... Generator Loss: 1.4195
# Epoch 1/2... Step 690 Discriminator Loss: 1.0965... Generator Loss: 0.8736
# Epoch 1/2... Step 700 Discriminator Loss: 1.0131... Generator Loss: 0.9436
# Epoch 1/2... Step 710 Discriminator Loss: 1.2588... Generator Loss: 0.7952
# Epoch 1/2... Step 720 Discriminator Loss: 1.1136... Generator Loss: 1.0134
# Epoch 1/2... Step 730 Discriminator Loss: 1.0524... Generator Loss: 1.0314
# Epoch 1/2... Step 740 Discriminator Loss: 1.2925... Generator Loss: 0.6550
# Epoch 1/2... Step 750 Discriminator Loss: 1.3488... Generator Loss: 0.6066
# Epoch 1/2... Step 760 Discriminator Loss: 0.9172... Generator Loss: 3.0813
# Epoch 1/2... Step 770 Discriminator Loss: 1.0311... Generator Loss: 1.6870
# Epoch 1/2... Step 780 Discriminator Loss: 1.2872... Generator Loss: 1.0827
# Epoch 1/2... Step 790 Discriminator Loss: 1.0910... Generator Loss: 0.8320
# Epoch 1/2... Step 800 Discriminator Loss: 1.6289... Generator Loss: 0.4391
# Epoch 1/2... Step 810 Discriminator Loss: 0.8626... Generator Loss: 1.7418
# Epoch 1/2... Step 820 Discriminator Loss: 1.4681... Generator Loss: 1.8365
# Epoch 1/2... Step 830 Discriminator Loss: 1.0939... Generator Loss: 1.0007
# Epoch 1/2... Step 840 Discriminator Loss: 0.9914... Generator Loss: 1.2278
# Epoch 1/2... Step 850 Discriminator Loss: 1.0760... Generator Loss: 1.2108
# Epoch 1/2... Step 860 Discriminator Loss: 1.1765... Generator Loss: 0.7321
# Epoch 1/2... Step 870 Discriminator Loss: 1.2647... Generator Loss: 0.7372
# Epoch 1/2... Step 880 Discriminator Loss: 1.3918... Generator Loss: 0.6455
# Epoch 1/2... Step 890 Discriminator Loss: 1.3881... Generator Loss: 0.5430
# Epoch 1/2... Step 900 Discriminator Loss: 0.9289... Generator Loss: 1.7351
# Epoch 1/2... Step 910 Discriminator Loss: 1.0308... Generator Loss: 1.7500
# Epoch 1/2... Step 920 Discriminator Loss: 1.2188... Generator Loss: 1.0419
# Epoch 1/2... Step 930 Discriminator Loss: 1.3145... Generator Loss: 0.7337
# Epoch 1/2... Step 940 Discriminator Loss: 1.1668... Generator Loss: 1.1097
# Epoch 1/2... Step 950 Discriminator Loss: 0.9991... Generator Loss: 1.1605
# Epoch 1/2... Step 960 Discriminator Loss: 1.0743... Generator Loss: 1.6024
# Epoch 1/2... Step 970 Discriminator Loss: 1.1314... Generator Loss: 1.4987
# Epoch 1/2... Step 980 Discriminator Loss: 1.3203... Generator Loss: 2.3575
# Epoch 1/2... Step 990 Discriminator Loss: 0.9927... Generator Loss: 1.0493
# Epoch 1/2... Step 1000 Discriminator Loss: 1.1543... Generator Loss: 1.0185
# Epoch 1/2... Step 1010 Discriminator Loss: 1.5588... Generator Loss: 0.4350
# Epoch 1/2... Step 1020 Discriminator Loss: 0.9383... Generator Loss: 1.2994
# Epoch 1/2... Step 1030 Discriminator Loss: 1.1374... Generator Loss: 0.8482
# Epoch 1/2... Step 1040 Discriminator Loss: 1.3267... Generator Loss: 0.7637
# Epoch 1/2... Step 1050 Discriminator Loss: 0.7301... Generator Loss: 1.7287
# Epoch 1/2... Step 1060 Discriminator Loss: 1.1197... Generator Loss: 1.6548
# Epoch 1/2... Step 1070 Discriminator Loss: 1.1014... Generator Loss: 1.3505
# Epoch 1/2... Step 1080 Discriminator Loss: 1.3171... Generator Loss: 0.7395
# Epoch 1/2... Step 1090 Discriminator Loss: 1.2891... Generator Loss: 0.5924
# Epoch 1/2... Step 1100 Discriminator Loss: 1.1285... Generator Loss: 0.8274
# Epoch 1/2... Step 1110 Discriminator Loss: 1.0217... Generator Loss: 1.2641
# Epoch 1/2... Step 1120 Discriminator Loss: 1.2792... Generator Loss: 0.6383
# Epoch 1/2... Step 1130 Discriminator Loss: 1.1297... Generator Loss: 1.5716
# Epoch 1/2... Step 1140 Discriminator Loss: 1.2486... Generator Loss: 0.7326
# Epoch 1/2... Step 1150 Discriminator Loss: 1.0448... Generator Loss: 1.9389
# Epoch 1/2... Step 1160 Discriminator Loss: 1.0785... Generator Loss: 1.2461
# Epoch 1/2... Step 1170 Discriminator Loss: 1.1152... Generator Loss: 1.1413
# Epoch 1/2... Step 1180 Discriminator Loss: 1.0767... Generator Loss: 0.8532
# Epoch 1/2... Step 1190 Discriminator Loss: 1.2947... Generator Loss: 0.9723
# Epoch 1/2... Step 1200 Discriminator Loss: 0.9754... Generator Loss: 1.7438
# Epoch 1/2... Step 1210 Discriminator Loss: 0.9391... Generator Loss: 1.2834
# Epoch 1/2... Step 1220 Discriminator Loss: 0.9757... Generator Loss: 1.5238
# Epoch 1/2... Step 1230 Discriminator Loss: 1.1104... Generator Loss: 0.8855
# Epoch 1/2... Step 1240 Discriminator Loss: 1.1155... Generator Loss: 1.8511
# Epoch 1/2... Step 1250 Discriminator Loss: 0.8889... Generator Loss: 1.5625
# Epoch 1/2... Step 1260 Discriminator Loss: 1.9003... Generator Loss: 0.2833
# Epoch 1/2... Step 1270 Discriminator Loss: 1.1122... Generator Loss: 0.9322
# Epoch 1/2... Step 1280 Discriminator Loss: 0.9768... Generator Loss: 1.8930
# Epoch 1/2... Step 1290 Discriminator Loss: 1.4346... Generator Loss: 0.5290
# Epoch 1/2... Step 1300 Discriminator Loss: 1.2074... Generator Loss: 0.7437
# Epoch 1/2... Step 1310 Discriminator Loss: 1.1170... Generator Loss: 1.4470
# Epoch 1/2... Step 1320 Discriminator Loss: 1.0607... Generator Loss: 0.8171
# Epoch 1/2... Step 1330 Discriminator Loss: 1.2770... Generator Loss: 0.7206
# Epoch 1/2... Step 1340 Discriminator Loss: 1.0886... Generator Loss: 1.0655
# Epoch 1/2... Step 1350 Discriminator Loss: 1.0747... Generator Loss: 1.0230
# Epoch 1/2... Step 1360 Discriminator Loss: 1.1829... Generator Loss: 0.7907
# Epoch 1/2... Step 1370 Discriminator Loss: 1.0159... Generator Loss: 0.9418
# Epoch 1/2... Step 1380 Discriminator Loss: 0.7583... Generator Loss: 1.6341
# Epoch 1/2... Step 1390 Discriminator Loss: 0.6229... Generator Loss: 2.1416
# Epoch 1/2... Step 1400 Discriminator Loss: 1.3226... Generator Loss: 0.5988
# Epoch 1/2... Step 1410 Discriminator Loss: 1.2750... Generator Loss: 2.6155
# Epoch 1/2... Step 1420 Discriminator Loss: 0.8993... Generator Loss: 1.2090
# Epoch 1/2... Step 1430 Discriminator Loss: 1.0551... Generator Loss: 2.1491
# Epoch 1/2... Step 1440 Discriminator Loss: 1.3886... Generator Loss: 0.5413
# Epoch 1/2... Step 1450 Discriminator Loss: 1.0455... Generator Loss: 1.0296
# Epoch 1/2... Step 1460 Discriminator Loss: 0.8257... Generator Loss: 1.4823
# Epoch 1/2... Step 1470 Discriminator Loss: 1.4389... Generator Loss: 0.5754
# Epoch 1/2... Step 1480 Discriminator Loss: 1.0511... Generator Loss: 0.9721
# Epoch 1/2... Step 1490 Discriminator Loss: 1.7838... Generator Loss: 0.3198
# Epoch 1/2... Step 1500 Discriminator Loss: 0.9191... Generator Loss: 1.5715
# Epoch 1/2... Step 1510 Discriminator Loss: 1.6991... Generator Loss: 0.4014
# Epoch 1/2... Step 1520 Discriminator Loss: 0.7032... Generator Loss: 1.5035
# Epoch 1/2... Step 1530 Discriminator Loss: 1.5967... Generator Loss: 0.4079
# Epoch 1/2... Step 1540 Discriminator Loss: 0.9212... Generator Loss: 1.1683
# Epoch 1/2... Step 1550 Discriminator Loss: 1.8992... Generator Loss: 0.3226
# Epoch 1/2... Step 1560 Discriminator Loss: 1.2083... Generator Loss: 0.7280
# Epoch 1/2... Step 1570 Discriminator Loss: 0.8703... Generator Loss: 1.4319
# Epoch 1/2... Step 1580 Discriminator Loss: 1.0204... Generator Loss: 1.3485
# Epoch 1/2... Step 1590 Discriminator Loss: 0.9297... Generator Loss: 1.0440
# Epoch 1/2... Step 1600 Discriminator Loss: 1.9106... Generator Loss: 0.3398
# Epoch 1/2... Step 1610 Discriminator Loss: 1.1237... Generator Loss: 0.7761
# Epoch 1/2... Step 1620 Discriminator Loss: 1.1825... Generator Loss: 0.8910
# Epoch 1/2... Step 1630 Discriminator Loss: 1.3221... Generator Loss: 1.9452
# Epoch 1/2... Step 1640 Discriminator Loss: 0.8178... Generator Loss: 1.2233
# Epoch 1/2... Step 1650 Discriminator Loss: 0.8305... Generator Loss: 1.5110
# Epoch 1/2... Step 1660 Discriminator Loss: 0.8151... Generator Loss: 1.5694
# Epoch 1/2... Step 1670 Discriminator Loss: 1.2088... Generator Loss: 1.2828
# Epoch 1/2... Step 1680 Discriminator Loss: 0.8270... Generator Loss: 1.2357
# Epoch 1/2... Step 1690 Discriminator Loss: 0.9078... Generator Loss: 1.5408
# Epoch 1/2... Step 1700 Discriminator Loss: 1.1567... Generator Loss: 0.9539
# Epoch 1/2... Step 1710 Discriminator Loss: 1.3054... Generator Loss: 0.6825
# Epoch 1/2... Step 1720 Discriminator Loss: 0.9294... Generator Loss: 1.2299
# Epoch 1/2... Step 1730 Discriminator Loss: 0.9781... Generator Loss: 1.5435
# Epoch 1/2... Step 1740 Discriminator Loss: 1.1358... Generator Loss: 1.0555
# Epoch 1/2... Step 1750 Discriminator Loss: 1.0004... Generator Loss: 1.0150
# Epoch 1/2... Step 1760 Discriminator Loss: 0.8403... Generator Loss: 1.2071
# Epoch 1/2... Step 1770 Discriminator Loss: 1.8342... Generator Loss: 0.5711
# Epoch 1/2... Step 1780 Discriminator Loss: 1.0235... Generator Loss: 1.8628
# Epoch 1/2... Step 1790 Discriminator Loss: 0.8329... Generator Loss: 1.4620
# Epoch 1/2... Step 1800 Discriminator Loss: 0.7324... Generator Loss: 1.3690
# Epoch 1/2... Step 1810 Discriminator Loss: 1.2132... Generator Loss: 2.0782
# Epoch 1/2... Step 1820 Discriminator Loss: 1.6139... Generator Loss: 0.4255
# Epoch 1/2... Step 1830 Discriminator Loss: 1.4067... Generator Loss: 0.5690
# Epoch 1/2... Step 1840 Discriminator Loss: 0.9202... Generator Loss: 1.2831
# Epoch 1/2... Step 1850 Discriminator Loss: 1.1609... Generator Loss: 0.7593
# Epoch 1/2... Step 1860 Discriminator Loss: 0.7747... Generator Loss: 1.4784
# Epoch 1/2... Step 1870 Discriminator Loss: 0.8709... Generator Loss: 1.2935
# Epoch 2/2... Step 1880 Discriminator Loss: 0.6479... Generator Loss: 2.2126
# Epoch 2/2... Step 1890 Discriminator Loss: 0.9859... Generator Loss: 0.9969
# Epoch 2/2... Step 1900 Discriminator Loss: 0.9077... Generator Loss: 1.1415
# Epoch 2/2... Step 1910 Discriminator Loss: 0.9867... Generator Loss: 0.9114
# Epoch 2/2... Step 1920 Discriminator Loss: 0.9099... Generator Loss: 0.9951
# Epoch 2/2... Step 1930 Discriminator Loss: 1.1047... Generator Loss: 0.9789
# Epoch 2/2... Step 1940 Discriminator Loss: 0.9107... Generator Loss: 1.4168
# Epoch 2/2... Step 1950 Discriminator Loss: 0.7763... Generator Loss: 1.3644
# Epoch 2/2... Step 1960 Discriminator Loss: 0.9668... Generator Loss: 1.0055
# Epoch 2/2... Step 1970 Discriminator Loss: 1.5374... Generator Loss: 0.4443
# Epoch 2/2... Step 1980 Discriminator Loss: 1.4240... Generator Loss: 0.5993
# Epoch 2/2... Step 1990 Discriminator Loss: 1.0786... Generator Loss: 0.8947
# Epoch 2/2... Step 2000 Discriminator Loss: 0.9801... Generator Loss: 1.1993
# Epoch 2/2... Step 2010 Discriminator Loss: 1.0048... Generator Loss: 0.9641
# Epoch 2/2... Step 2020 Discriminator Loss: 0.8400... Generator Loss: 1.2937
# Epoch 2/2... Step 2030 Discriminator Loss: 0.9268... Generator Loss: 0.9906
# Epoch 2/2... Step 2040 Discriminator Loss: 1.0428... Generator Loss: 0.9116
# Epoch 2/2... Step 2050 Discriminator Loss: 0.8960... Generator Loss: 1.2087
# Epoch 2/2... Step 2060 Discriminator Loss: 0.6392... Generator Loss: 1.6803
# Epoch 2/2... Step 2070 Discriminator Loss: 0.7640... Generator Loss: 1.9378
# Epoch 2/2... Step 2080 Discriminator Loss: 2.5900... Generator Loss: 0.1719
# Epoch 2/2... Step 2090 Discriminator Loss: 1.0525... Generator Loss: 0.9117
# Epoch 2/2... Step 2100 Discriminator Loss: 0.6502... Generator Loss: 1.8831
# Epoch 2/2... Step 2110 Discriminator Loss: 1.0873... Generator Loss: 0.8045
# Epoch 2/2... Step 2120 Discriminator Loss: 0.7606... Generator Loss: 2.5698
# Epoch 2/2... Step 2130 Discriminator Loss: 0.6809... Generator Loss: 1.4794
# Epoch 2/2... Step 2140 Discriminator Loss: 1.0753... Generator Loss: 2.6573
# Epoch 2/2... Step 2150 Discriminator Loss: 1.5767... Generator Loss: 0.4397
# Epoch 2/2... Step 2160 Discriminator Loss: 1.6192... Generator Loss: 0.4657
# Epoch 2/2... Step 2170 Discriminator Loss: 1.4048... Generator Loss: 0.6392
# Epoch 2/2... Step 2180 Discriminator Loss: 1.2790... Generator Loss: 0.6741
# Epoch 2/2... Step 2190 Discriminator Loss: 0.5645... Generator Loss: 1.7783
# Epoch 2/2... Step 2200 Discriminator Loss: 0.8880... Generator Loss: 1.0999
# Epoch 2/2... Step 2210 Discriminator Loss: 1.0353... Generator Loss: 0.8737
# Epoch 2/2... Step 2220 Discriminator Loss: 0.6571... Generator Loss: 2.4085
# Epoch 2/2... Step 2230 Discriminator Loss: 1.7917... Generator Loss: 0.3742
# Epoch 2/2... Step 2240 Discriminator Loss: 0.6798... Generator Loss: 1.8170
# Epoch 2/2... Step 2250 Discriminator Loss: 1.8639... Generator Loss: 0.4408
# Epoch 2/2... Step 2260 Discriminator Loss: 1.0178... Generator Loss: 0.8896
# Epoch 2/2... Step 2270 Discriminator Loss: 1.4183... Generator Loss: 0.5524
# Epoch 2/2... Step 2280 Discriminator Loss: 1.0579... Generator Loss: 0.9186
# Epoch 2/2... Step 2290 Discriminator Loss: 0.9936... Generator Loss: 1.9851
# Epoch 2/2... Step 2300 Discriminator Loss: 1.0325... Generator Loss: 1.7854
# Epoch 2/2... Step 2310 Discriminator Loss: 0.8364... Generator Loss: 1.6388
# Epoch 2/2... Step 2320 Discriminator Loss: 1.2303... Generator Loss: 0.7515
# Epoch 2/2... Step 2330 Discriminator Loss: 1.1661... Generator Loss: 1.9663
# Epoch 2/2... Step 2340 Discriminator Loss: 1.0089... Generator Loss: 0.9787
# Epoch 2/2... Step 2350 Discriminator Loss: 0.7466... Generator Loss: 1.4143
# Epoch 2/2... Step 2360 Discriminator Loss: 1.5366... Generator Loss: 0.6628
# Epoch 2/2... Step 2370 Discriminator Loss: 1.1218... Generator Loss: 1.8962
# Epoch 2/2... Step 2380 Discriminator Loss: 1.1583... Generator Loss: 0.8513
# Epoch 2/2... Step 2390 Discriminator Loss: 0.9913... Generator Loss: 0.9093
# Epoch 2/2... Step 2400 Discriminator Loss: 1.0331... Generator Loss: 0.8538
# Epoch 2/2... Step 2410 Discriminator Loss: 0.7745... Generator Loss: 1.7240
# Epoch 2/2... Step 2420 Discriminator Loss: 0.7116... Generator Loss: 1.5800
# Epoch 2/2... Step 2430 Discriminator Loss: 0.8889... Generator Loss: 1.0649
# Epoch 2/2... Step 2440 Discriminator Loss: 0.7288... Generator Loss: 1.6131
# Epoch 2/2... Step 2450 Discriminator Loss: 0.7516... Generator Loss: 1.6805
# Epoch 2/2... Step 2460 Discriminator Loss: 1.0133... Generator Loss: 0.8634
# Epoch 2/2... Step 2470 Discriminator Loss: 2.0381... Generator Loss: 0.3159
# Epoch 2/2... Step 2480 Discriminator Loss: 1.1430... Generator Loss: 0.8168
# Epoch 2/2... Step 2490 Discriminator Loss: 0.8890... Generator Loss: 1.2070
# Epoch 2/2... Step 2500 Discriminator Loss: 1.4200... Generator Loss: 0.6003
# Epoch 2/2... Step 2510 Discriminator Loss: 1.1896... Generator Loss: 0.7314
# Epoch 2/2... Step 2520 Discriminator Loss: 0.8656... Generator Loss: 2.1477
# Epoch 2/2... Step 2530 Discriminator Loss: 1.6701... Generator Loss: 0.3713
# Epoch 2/2... Step 2540 Discriminator Loss: 1.0718... Generator Loss: 0.8477
# Epoch 2/2... Step 2550 Discriminator Loss: 1.5796... Generator Loss: 0.4965
# Epoch 2/2... Step 2560 Discriminator Loss: 0.9361... Generator Loss: 1.0679
# Epoch 2/2... Step 2570 Discriminator Loss: 0.7424... Generator Loss: 1.4519
# Epoch 2/2... Step 2580 Discriminator Loss: 0.8731... Generator Loss: 1.3678
# Epoch 2/2... Step 2590 Discriminator Loss: 0.9279... Generator Loss: 1.4613
# Epoch 2/2... Step 2600 Discriminator Loss: 0.9102... Generator Loss: 1.2034
# Epoch 2/2... Step 2610 Discriminator Loss: 1.1052... Generator Loss: 0.7275
# Epoch 2/2... Step 2620 Discriminator Loss: 0.6005... Generator Loss: 1.8558
# Epoch 2/2... Step 2630 Discriminator Loss: 0.8370... Generator Loss: 1.0978
# Epoch 2/2... Step 2640 Discriminator Loss: 1.5168... Generator Loss: 0.6605
# Epoch 2/2... Step 2650 Discriminator Loss: 1.1899... Generator Loss: 0.7876
# Epoch 2/2... Step 2660 Discriminator Loss: 0.7940... Generator Loss: 1.7494
# Epoch 2/2... Step 2670 Discriminator Loss: 0.6913... Generator Loss: 1.3927
# Epoch 2/2... Step 2680 Discriminator Loss: 0.7446... Generator Loss: 1.5548
# Epoch 2/2... Step 2690 Discriminator Loss: 0.8980... Generator Loss: 1.1381
# Epoch 2/2... Step 2700 Discriminator Loss: 0.9253... Generator Loss: 1.2795
# Epoch 2/2... Step 2710 Discriminator Loss: 0.6926... Generator Loss: 1.6367
# Epoch 2/2... Step 2720 Discriminator Loss: 0.9838... Generator Loss: 0.9657
# Epoch 2/2... Step 2730 Discriminator Loss: 1.8890... Generator Loss: 0.3153
# Epoch 2/2... Step 2740 Discriminator Loss: 0.7548... Generator Loss: 1.4704
# Epoch 2/2... Step 2750 Discriminator Loss: 0.7299... Generator Loss: 1.6285
# Epoch 2/2... Step 2760 Discriminator Loss: 1.1574... Generator Loss: 0.9588
# Epoch 2/2... Step 2770 Discriminator Loss: 0.9421... Generator Loss: 1.1172
# Epoch 2/2... Step 2780 Discriminator Loss: 0.8892... Generator Loss: 2.1323
# Epoch 2/2... Step 2790 Discriminator Loss: 0.8784... Generator Loss: 1.2210
# Epoch 2/2... Step 2800 Discriminator Loss: 0.8613... Generator Loss: 1.0847
# Epoch 2/2... Step 2810 Discriminator Loss: 1.0995... Generator Loss: 1.9956
# Epoch 2/2... Step 2820 Discriminator Loss: 0.9194... Generator Loss: 0.9524
# Epoch 2/2... Step 2830 Discriminator Loss: 0.5609... Generator Loss: 2.4622
# Epoch 2/2... Step 2840 Discriminator Loss: 1.1387... Generator Loss: 0.7307
# Epoch 2/2... Step 2850 Discriminator Loss: 2.1007... Generator Loss: 0.3357
# Epoch 2/2... Step 2860 Discriminator Loss: 1.2999... Generator Loss: 0.6482
# Epoch 2/2... Step 2870 Discriminator Loss: 0.8474... Generator Loss: 1.2165
# Epoch 2/2... Step 2880 Discriminator Loss: 0.6223... Generator Loss: 1.7228
# Epoch 2/2... Step 2890 Discriminator Loss: 0.8957... Generator Loss: 1.8877
# Epoch 2/2... Step 2900 Discriminator Loss: 0.7996... Generator Loss: 1.4782
# Epoch 2/2... Step 2910 Discriminator Loss: 0.7059... Generator Loss: 2.7512
# Epoch 2/2... Step 2920 Discriminator Loss: 1.7895... Generator Loss: 0.3895
# Epoch 2/2... Step 2930 Discriminator Loss: 0.6876... Generator Loss: 1.8607
# Epoch 2/2... Step 2940 Discriminator Loss: 1.2330... Generator Loss: 0.7118
# Epoch 2/2... Step 2950 Discriminator Loss: 0.7964... Generator Loss: 1.3973
# Epoch 2/2... Step 2960 Discriminator Loss: 0.8339... Generator Loss: 1.2728
# Epoch 2/2... Step 2970 Discriminator Loss: 0.7223... Generator Loss: 1.4270
# Epoch 2/2... Step 2980 Discriminator Loss: 0.7321... Generator Loss: 1.3431
# Epoch 2/2... Step 2990 Discriminator Loss: 0.9838... Generator Loss: 1.0072
# Epoch 2/2... Step 3000 Discriminator Loss: 0.7938... Generator Loss: 1.3837
# Epoch 2/2... Step 3010 Discriminator Loss: 1.3175... Generator Loss: 0.6372
# Epoch 2/2... Step 3020 Discriminator Loss: 0.5510... Generator Loss: 2.2286
# Epoch 2/2... Step 3030 Discriminator Loss: 0.7292... Generator Loss: 2.3786
# Epoch 2/2... Step 3040 Discriminator Loss: 1.3257... Generator Loss: 0.5935
# Epoch 2/2... Step 3050 Discriminator Loss: 0.9015... Generator Loss: 1.0520
# Epoch 2/2... Step 3060 Discriminator Loss: 0.8164... Generator Loss: 1.3441
# Epoch 2/2... Step 3070 Discriminator Loss: 0.8762... Generator Loss: 1.1246
# Epoch 2/2... Step 3080 Discriminator Loss: 0.7752... Generator Loss: 2.2662
# Epoch 2/2... Step 3090 Discriminator Loss: 2.6924... Generator Loss: 0.1744
# Epoch 2/2... Step 3100 Discriminator Loss: 0.9032... Generator Loss: 1.0783
# Epoch 2/2... Step 3110 Discriminator Loss: 0.6711... Generator Loss: 1.7783
# Epoch 2/2... Step 3120 Discriminator Loss: 0.8295... Generator Loss: 1.4569
# Epoch 2/2... Step 3130 Discriminator Loss: 1.3213... Generator Loss: 2.8985
# Epoch 2/2... Step 3140 Discriminator Loss: 1.3992... Generator Loss: 0.6905
# Epoch 2/2... Step 3150 Discriminator Loss: 2.0453... Generator Loss: 0.3695
# Epoch 2/2... Step 3160 Discriminator Loss: 0.6537... Generator Loss: 1.7247
# Epoch 2/2... Step 3170 Discriminator Loss: 1.1827... Generator Loss: 0.7336
# Epoch 2/2... Step 3180 Discriminator Loss: 1.0353... Generator Loss: 0.8868
# Epoch 2/2... Step 3190 Discriminator Loss: 0.9735... Generator Loss: 0.9879
# Epoch 2/2... Step 3200 Discriminator Loss: 0.8758... Generator Loss: 1.4300
# Epoch 2/2... Step 3210 Discriminator Loss: 0.9950... Generator Loss: 0.9444
# Epoch 2/2... Step 3220 Discriminator Loss: 1.0647... Generator Loss: 0.9012
# Epoch 2/2... Step 3230 Discriminator Loss: 0.9975... Generator Loss: 1.7008
# Epoch 2/2... Step 3240 Discriminator Loss: 0.8455... Generator Loss: 1.1944
# Epoch 2/2... Step 3250 Discriminator Loss: 0.6718... Generator Loss: 1.6959
# Epoch 2/2... Step 3260 Discriminator Loss: 0.9672... Generator Loss: 0.9812
# Epoch 2/2... Step 3270 Discriminator Loss: 0.6201... Generator Loss: 2.2548
# Epoch 2/2... Step 3280 Discriminator Loss: 1.3810... Generator Loss: 0.6892
# Epoch 2/2... Step 3290 Discriminator Loss: 2.1487... Generator Loss: 0.3643
# Epoch 2/2... Step 3300 Discriminator Loss: 0.7523... Generator Loss: 2.4317
# Epoch 2/2... Step 3310 Discriminator Loss: 1.1712... Generator Loss: 0.8083
# Epoch 2/2... Step 3320 Discriminator Loss: 0.9979... Generator Loss: 1.0101
# Epoch 2/2... Step 3330 Discriminator Loss: 0.6983... Generator Loss: 1.5651
# Epoch 2/2... Step 3340 Discriminator Loss: 0.6936... Generator Loss: 1.7050
# Epoch 2/2... Step 3350 Discriminator Loss: 1.1330... Generator Loss: 0.8159
# Epoch 2/2... Step 3360 Discriminator Loss: 0.8260... Generator Loss: 1.1466
# Epoch 2/2... Step 3370 Discriminator Loss: 1.5339... Generator Loss: 0.5523
# Epoch 2/2... Step 3380 Discriminator Loss: 0.6892... Generator Loss: 1.8006
# Epoch 2/2... Step 3390 Discriminator Loss: 0.6702... Generator Loss: 2.4449
# Epoch 2/2... Step 3400 Discriminator Loss: 1.4916... Generator Loss: 0.5492
# Epoch 2/2... Step 3410 Discriminator Loss: 0.9893... Generator Loss: 1.0007
# Epoch 2/2... Step 3420 Discriminator Loss: 0.6417... Generator Loss: 2.1001
# Epoch 2/2... Step 3430 Discriminator Loss: 1.1917... Generator Loss: 0.7154
# Epoch 2/2... Step 3440 Discriminator Loss: 1.5765... Generator Loss: 0.5449
# Epoch 2/2... Step 3450 Discriminator Loss: 0.8386... Generator Loss: 1.2205
# Epoch 2/2... Step 3460 Discriminator Loss: 0.8814... Generator Loss: 1.1131
# Epoch 2/2... Step 3470 Discriminator Loss: 0.6863... Generator Loss: 1.5578
# Epoch 2/2... Step 3480 Discriminator Loss: 0.7544... Generator Loss: 1.2381
# Epoch 2/2... Step 3490 Discriminator Loss: 1.3896... Generator Loss: 2.4139
# Epoch 2/2... Step 3500 Discriminator Loss: 0.8268... Generator Loss: 1.5838
# Epoch 2/2... Step 3510 Discriminator Loss: 2.9021... Generator Loss: 0.1897
# Epoch 2/2... Step 3520 Discriminator Loss: 0.6380... Generator Loss: 2.2984
# Epoch 2/2... Step 3530 Discriminator Loss: 0.9962... Generator Loss: 0.9383
# Epoch 2/2... Step 3540 Discriminator Loss: 0.8970... Generator Loss: 1.0773
# Epoch 2/2... Step 3550 Discriminator Loss: 1.3220... Generator Loss: 0.7096
# Epoch 2/2... Step 3560 Discriminator Loss: 1.1242... Generator Loss: 0.8578
# Epoch 2/2... Step 3570 Discriminator Loss: 0.7642... Generator Loss: 1.3301
# Epoch 2/2... Step 3580 Discriminator Loss: 1.6250... Generator Loss: 0.4348
# Epoch 2/2... Step 3590 Discriminator Loss: 1.7519... Generator Loss: 0.6260
# Epoch 2/2... Step 3600 Discriminator Loss: 0.8505... Generator Loss: 1.3688
# Epoch 2/2... Step 3610 Discriminator Loss: 0.5925... Generator Loss: 2.7041
# Epoch 2/2... Step 3620 Discriminator Loss: 0.8483... Generator Loss: 1.9845
# Epoch 2/2... Step 3630 Discriminator Loss: 0.8175... Generator Loss: 1.0986
# Epoch 2/2... Step 3640 Discriminator Loss: 1.5484... Generator Loss: 0.5229
# Epoch 2/2... Step 3650 Discriminator Loss: 0.8435... Generator Loss: 1.3171
# Epoch 2/2... Step 3660 Discriminator Loss: 0.7798... Generator Loss: 1.3606
# Epoch 2/2... Step 3670 Discriminator Loss: 1.1266... Generator Loss: 1.8137
# Epoch 2/2... Step 3680 Discriminator Loss: 0.9795... Generator Loss: 1.0683
# Epoch 2/2... Step 3690 Discriminator Loss: 1.0195... Generator Loss: 0.8785
# Epoch 2/2... Step 3700 Discriminator Loss: 1.0381... Generator Loss: 0.9500
# Epoch 2/2... Step 3710 Discriminator Loss: 0.5710... Generator Loss: 2.6921
# Epoch 2/2... Step 3720 Discriminator Loss: 1.7753... Generator Loss: 0.4897
# Epoch 2/2... Step 3730 Discriminator Loss: 0.9375... Generator Loss: 1.0339
# Epoch 2/2... Step 3740 Discriminator Loss: 0.7986... Generator Loss: 1.2037
# Epoch 2/2... Step 3750 Discriminator Loss: 0.6179... Generator Loss: 1.8514

# %% [markdown]
# ### CelebA
# Run your GANs on CelebA.  It will take around 20 minutes on the average GPU to run one epoch.  You can run the whole epoch or stop when it starts to generate realistic faces.

# %%
batch_size = 32
z_dim = 100
learning_rate = 0.001
beta1 = 0.4
#tf.reset_default_graph()

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
epochs = 1

celeba_dataset = helper.Dataset('celeba', glob(os.path.join(data_dir, 'img_align_celeba/*.jpg')))
with tf.Graph().as_default():
    train(epochs, batch_size, z_dim, learning_rate, beta1, celeba_dataset.get_batches,
          celeba_dataset.shape, celeba_dataset.image_mode)
# Out:
# Epoch 1/1... Step 10 Discriminator Loss: 0.5152... Generator Loss: 10.4203
# Epoch 1/1... Step 20 Discriminator Loss: 0.6014... Generator Loss: 2.5560
# Epoch 1/1... Step 30 Discriminator Loss: 0.4836... Generator Loss: 3.3698
# Epoch 1/1... Step 40 Discriminator Loss: 0.5846... Generator Loss: 5.6418
# Epoch 1/1... Step 50 Discriminator Loss: 0.6109... Generator Loss: 1.9019
# Epoch 1/1... Step 60 Discriminator Loss: 0.3806... Generator Loss: 4.2912
# Epoch 1/1... Step 70 Discriminator Loss: 0.7503... Generator Loss: 1.5510
# Epoch 1/1... Step 80 Discriminator Loss: 0.6455... Generator Loss: 2.0360
# Epoch 1/1... Step 90 Discriminator Loss: 0.4206... Generator Loss: 8.1186
# Epoch 1/1... Step 100 Discriminator Loss: 0.5816... Generator Loss: 2.5658
# Epoch 1/1... Step 110 Discriminator Loss: 0.4226... Generator Loss: 3.8270
# Epoch 1/1... Step 120 Discriminator Loss: 0.4139... Generator Loss: 7.0538
# Epoch 1/1... Step 130 Discriminator Loss: 0.3838... Generator Loss: 3.9472
# Epoch 1/1... Step 140 Discriminator Loss: 0.4290... Generator Loss: 2.9799
# Epoch 1/1... Step 150 Discriminator Loss: 0.3996... Generator Loss: 3.3440
# Epoch 1/1... Step 160 Discriminator Loss: 0.3954... Generator Loss: 4.0911
# Epoch 1/1... Step 170 Discriminator Loss: 1.4695... Generator Loss: 0.5804
# Epoch 1/1... Step 180 Discriminator Loss: 0.8386... Generator Loss: 1.2756
# Epoch 1/1... Step 190 Discriminator Loss: 0.5392... Generator Loss: 4.5648
# Epoch 1/1... Step 200 Discriminator Loss: 0.4724... Generator Loss: 2.8192
# Epoch 1/1... Step 210 Discriminator Loss: 0.4775... Generator Loss: 2.6539
# Epoch 1/1... Step 220 Discriminator Loss: 0.4069... Generator Loss: 3.4954
# Epoch 1/1... Step 230 Discriminator Loss: 0.6290... Generator Loss: 3.8744
# Epoch 1/1... Step 240 Discriminator Loss: 0.7163... Generator Loss: 2.2102
# Epoch 1/1... Step 250 Discriminator Loss: 1.1018... Generator Loss: 4.5363
# Epoch 1/1... Step 260 Discriminator Loss: 0.9975... Generator Loss: 1.2555
# Epoch 1/1... Step 270 Discriminator Loss: 0.9342... Generator Loss: 1.1520
# Epoch 1/1... Step 280 Discriminator Loss: 1.1379... Generator Loss: 1.0047
# Epoch 1/1... Step 290 Discriminator Loss: 0.7032... Generator Loss: 3.4336
# Epoch 1/1... Step 300 Discriminator Loss: 0.4736... Generator Loss: 2.5792
# Epoch 1/1... Step 310 Discriminator Loss: 0.8748... Generator Loss: 1.1386
# Epoch 1/1... Step 320 Discriminator Loss: 0.4529... Generator Loss: 3.0405
# Epoch 1/1... Step 330 Discriminator Loss: 1.2006... Generator Loss: 0.8591
# Epoch 1/1... Step 340 Discriminator Loss: 1.0099... Generator Loss: 1.3013
# Epoch 1/1... Step 350 Discriminator Loss: 0.7050... Generator Loss: 1.9851
# Epoch 1/1... Step 360 Discriminator Loss: 0.6239... Generator Loss: 2.9720
# Epoch 1/1... Step 370 Discriminator Loss: 0.7715... Generator Loss: 4.6346
# Epoch 1/1... Step 380 Discriminator Loss: 0.8108... Generator Loss: 1.6527
# Epoch 1/1... Step 390 Discriminator Loss: 0.7762... Generator Loss: 3.3005
# Epoch 1/1... Step 400 Discriminator Loss: 0.9769... Generator Loss: 1.5228
# Epoch 1/1... Step 410 Discriminator Loss: 0.8898... Generator Loss: 2.6471
# Epoch 1/1... Step 420 Discriminator Loss: 0.5962... Generator Loss: 2.6070
# Epoch 1/1... Step 430 Discriminator Loss: 0.8136... Generator Loss: 1.4771
# Epoch 1/1... Step 440 Discriminator Loss: 1.2030... Generator Loss: 0.6800
# Epoch 1/1... Step 450 Discriminator Loss: 0.8308... Generator Loss: 1.2040
# Epoch 1/1... Step 460 Discriminator Loss: 1.4396... Generator Loss: 0.6383
# Epoch 1/1... Step 470 Discriminator Loss: 2.7803... Generator Loss: 0.2172
# Epoch 1/1... Step 480 Discriminator Loss: 0.8177... Generator Loss: 2.1671
# Epoch 1/1... Step 490 Discriminator Loss: 0.6472... Generator Loss: 2.8197
# Epoch 1/1... Step 500 Discriminator Loss: 1.7131... Generator Loss: 0.3410
# Epoch 1/1... Step 510 Discriminator Loss: 0.8516... Generator Loss: 1.4991
# Epoch 1/1... Step 520 Discriminator Loss: 0.5678... Generator Loss: 2.1696
# Epoch 1/1... Step 530 Discriminator Loss: 0.8141... Generator Loss: 2.4595
# Epoch 1/1... Step 540 Discriminator Loss: 0.5898... Generator Loss: 2.5046
# Epoch 1/1... Step 550 Discriminator Loss: 0.8712... Generator Loss: 1.9387
# Epoch 1/1... Step 560 Discriminator Loss: 1.3235... Generator Loss: 0.8624
# Epoch 1/1... Step 570 Discriminator Loss: 0.7748... Generator Loss: 1.2392
# Epoch 1/1... Step 580 Discriminator Loss: 0.6028... Generator Loss: 3.1697
# Epoch 1/1... Step 590 Discriminator Loss: 1.4627... Generator Loss: 0.4825
# Epoch 1/1... Step 600 Discriminator Loss: 0.8585... Generator Loss: 2.3073
# Epoch 1/1... Step 610 Discriminator Loss: 1.0829... Generator Loss: 2.6895
# Epoch 1/1... Step 620 Discriminator Loss: 0.8918... Generator Loss: 1.9511
# Epoch 1/1... Step 630 Discriminator Loss: 0.6771... Generator Loss: 3.6607
# Epoch 1/1... Step 640 Discriminator Loss: 0.7728... Generator Loss: 2.0232
# Epoch 1/1... Step 650 Discriminator Loss: 1.1178... Generator Loss: 0.8851
# Epoch 1/1... Step 660 Discriminator Loss: 1.0506... Generator Loss: 1.0553
# Epoch 1/1... Step 670 Discriminator Loss: 0.4942... Generator Loss: 2.7021
# Epoch 1/1... Step 680 Discriminator Loss: 0.7002... Generator Loss: 1.7564
# Epoch 1/1... Step 690 Discriminator Loss: 0.7873... Generator Loss: 3.3365
# Epoch 1/1... Step 700 Discriminator Loss: 0.7226... Generator Loss: 1.7845
# Epoch 1/1... Step 710 Discriminator Loss: 0.5499... Generator Loss: 2.6889
# Epoch 1/1... Step 720 Discriminator Loss: 1.2073... Generator Loss: 0.8006
# Epoch 1/1... Step 730 Discriminator Loss: 0.6541... Generator Loss: 3.4507
# Epoch 1/1... Step 740 Discriminator Loss: 1.1267... Generator Loss: 1.1342
# Epoch 1/1... Step 750 Discriminator Loss: 0.7020... Generator Loss: 2.7864
# Epoch 1/1... Step 760 Discriminator Loss: 0.5467... Generator Loss: 2.0875
# Epoch 1/1... Step 770 Discriminator Loss: 0.6352... Generator Loss: 3.2488
# Epoch 1/1... Step 780 Discriminator Loss: 0.8448... Generator Loss: 1.9425
# Epoch 1/1... Step 790 Discriminator Loss: 0.6434... Generator Loss: 1.6442
# Epoch 1/1... Step 800 Discriminator Loss: 0.9268... Generator Loss: 1.0901
# Epoch 1/1... Step 810 Discriminator Loss: 0.6062... Generator Loss: 3.3093
# Epoch 1/1... Step 820 Discriminator Loss: 1.0966... Generator Loss: 2.6123
# Epoch 1/1... Step 830 Discriminator Loss: 1.0867... Generator Loss: 0.8053
# Epoch 1/1... Step 840 Discriminator Loss: 0.5643... Generator Loss: 2.3166
# Epoch 1/1... Step 850 Discriminator Loss: 1.1061... Generator Loss: 0.8644
# Epoch 1/1... Step 860 Discriminator Loss: 0.6834... Generator Loss: 2.5156
# Epoch 1/1... Step 870 Discriminator Loss: 0.9050... Generator Loss: 3.3277
# Epoch 1/1... Step 880 Discriminator Loss: 0.4708... Generator Loss: 3.0952
# Epoch 1/1... Step 890 Discriminator Loss: 0.6873... Generator Loss: 1.9832
# Epoch 1/1... Step 900 Discriminator Loss: 0.7050... Generator Loss: 2.1995
# Epoch 1/1... Step 910 Discriminator Loss: 0.6104... Generator Loss: 2.5436
# Epoch 1/1... Step 920 Discriminator Loss: 0.8577... Generator Loss: 1.1419
# Epoch 1/1... Step 930 Discriminator Loss: 0.7237... Generator Loss: 1.9063
# Epoch 1/1... Step 940 Discriminator Loss: 1.7836... Generator Loss: 0.4745
# Epoch 1/1... Step 950 Discriminator Loss: 1.1233... Generator Loss: 1.6914
# Epoch 1/1... Step 960 Discriminator Loss: 1.5919... Generator Loss: 0.4440
# Epoch 1/1... Step 970 Discriminator Loss: 0.6366... Generator Loss: 1.7327
# Epoch 1/1... Step 980 Discriminator Loss: 0.6887... Generator Loss: 3.2254
# Epoch 1/1... Step 990 Discriminator Loss: 0.7065... Generator Loss: 1.6720
# Epoch 1/1... Step 1000 Discriminator Loss: 0.6757... Generator Loss: 2.3026
# Epoch 1/1... Step 1010 Discriminator Loss: 0.6880... Generator Loss: 1.6056
# Epoch 1/1... Step 1020 Discriminator Loss: 0.6480... Generator Loss: 1.6690
# Epoch 1/1... Step 1030 Discriminator Loss: 1.3845... Generator Loss: 3.3648
# Epoch 1/1... Step 1040 Discriminator Loss: 0.6756... Generator Loss: 1.8164
# Epoch 1/1... Step 1050 Discriminator Loss: 0.9276... Generator Loss: 1.2641
# Epoch 1/1... Step 1060 Discriminator Loss: 0.7662... Generator Loss: 1.3382
# Epoch 1/1... Step 1070 Discriminator Loss: 0.6794... Generator Loss: 3.6494
# Epoch 1/1... Step 1080 Discriminator Loss: 0.9740... Generator Loss: 1.0687
# Epoch 1/1... Step 1090 Discriminator Loss: 1.0819... Generator Loss: 1.0592
# Epoch 1/1... Step 1100 Discriminator Loss: 0.7328... Generator Loss: 2.5043
# Epoch 1/1... Step 1110 Discriminator Loss: 0.9607... Generator Loss: 1.0969
# Epoch 1/1... Step 1120 Discriminator Loss: 0.8695... Generator Loss: 1.5500
# Epoch 1/1... Step 1130 Discriminator Loss: 0.6878... Generator Loss: 1.7048
# Epoch 1/1... Step 1140 Discriminator Loss: 1.0527... Generator Loss: 0.9763
# Epoch 1/1... Step 1150 Discriminator Loss: 0.7579... Generator Loss: 1.6700
# Epoch 1/1... Step 1160 Discriminator Loss: 0.7244... Generator Loss: 1.3687
# Epoch 1/1... Step 1170 Discriminator Loss: 1.7861... Generator Loss: 4.5263
# Epoch 1/1... Step 1180 Discriminator Loss: 0.8503... Generator Loss: 1.3295
# Epoch 1/1... Step 1190 Discriminator Loss: 0.6969... Generator Loss: 1.6501
# Epoch 1/1... Step 1200 Discriminator Loss: 0.5470... Generator Loss: 3.4586
# Epoch 1/1... Step 1210 Discriminator Loss: 1.6315... Generator Loss: 0.4663
# Epoch 1/1... Step 1220 Discriminator Loss: 0.6893... Generator Loss: 4.3494
# Epoch 1/1... Step 1230 Discriminator Loss: 0.6949... Generator Loss: 2.1073
# Epoch 1/1... Step 1240 Discriminator Loss: 0.6013... Generator Loss: 2.7674
# Epoch 1/1... Step 1250 Discriminator Loss: 0.5990... Generator Loss: 4.5560
# Epoch 1/1... Step 1260 Discriminator Loss: 0.6315... Generator Loss: 1.8737
# Epoch 1/1... Step 1270 Discriminator Loss: 0.7722... Generator Loss: 1.8658
# Epoch 1/1... Step 1280 Discriminator Loss: 0.7156... Generator Loss: 1.7016
# Epoch 1/1... Step 1290 Discriminator Loss: 0.8401... Generator Loss: 1.1794
# Epoch 1/1... Step 1300 Discriminator Loss: 0.7858... Generator Loss: 1.5540
# Epoch 1/1... Step 1310 Discriminator Loss: 0.5966... Generator Loss: 2.1917
# Epoch 1/1... Step 1320 Discriminator Loss: 1.0163... Generator Loss: 2.4012
# Epoch 1/1... Step 1330 Discriminator Loss: 0.6589... Generator Loss: 2.4771
# Epoch 1/1... Step 1340 Discriminator Loss: 0.7284... Generator Loss: 1.8910
# Epoch 1/1... Step 1350 Discriminator Loss: 0.5868... Generator Loss: 2.1761
# Epoch 1/1... Step 1360 Discriminator Loss: 0.8753... Generator Loss: 2.4944
# Epoch 1/1... Step 1370 Discriminator Loss: 0.6889... Generator Loss: 1.8596
# Epoch 1/1... Step 1380 Discriminator Loss: 0.6337... Generator Loss: 1.6694
# Epoch 1/1... Step 1390 Discriminator Loss: 0.7262... Generator Loss: 1.6108
# Epoch 1/1... Step 1400 Discriminator Loss: 0.6823... Generator Loss: 2.7231
# Epoch 1/1... Step 1410 Discriminator Loss: 0.5378... Generator Loss: 3.6522
# Epoch 1/1... Step 1420 Discriminator Loss: 1.1357... Generator Loss: 0.7893
# Epoch 1/1... Step 1430 Discriminator Loss: 0.7779... Generator Loss: 1.2993
# Epoch 1/1... Step 1440 Discriminator Loss: 0.7192... Generator Loss: 1.5594
# Epoch 1/1... Step 1450 Discriminator Loss: 0.7702... Generator Loss: 1.9075
# Epoch 1/1... Step 1460 Discriminator Loss: 0.5458... Generator Loss: 2.1231
# Epoch 1/1... Step 1470 Discriminator Loss: 1.0098... Generator Loss: 0.9346
# Epoch 1/1... Step 1480 Discriminator Loss: 0.5747... Generator Loss: 2.1482
# Epoch 1/1... Step 1490 Discriminator Loss: 0.7920... Generator Loss: 1.5211
# Epoch 1/1... Step 1500 Discriminator Loss: 0.8347... Generator Loss: 1.6613
# Epoch 1/1... Step 1510 Discriminator Loss: 0.6097... Generator Loss: 3.2032
# Epoch 1/1... Step 1520 Discriminator Loss: 0.8460... Generator Loss: 1.1848
# Epoch 1/1... Step 1530 Discriminator Loss: 0.7850... Generator Loss: 1.5308
# Epoch 1/1... Step 1540 Discriminator Loss: 0.8861... Generator Loss: 1.3323
# Epoch 1/1... Step 1550 Discriminator Loss: 0.5580... Generator Loss: 2.2898
# Epoch 1/1... Step 1560 Discriminator Loss: 0.8042... Generator Loss: 1.4490
# Epoch 1/1... Step 1570 Discriminator Loss: 0.6378... Generator Loss: 2.0329
# Epoch 1/1... Step 1580 Discriminator Loss: 0.7288... Generator Loss: 1.6127
# Epoch 1/1... Step 1590 Discriminator Loss: 0.6644... Generator Loss: 2.3127
# Epoch 1/1... Step 1600 Discriminator Loss: 0.5087... Generator Loss: 2.3974
# Epoch 1/1... Step 1610 Discriminator Loss: 0.6360... Generator Loss: 2.0988
# Epoch 1/1... Step 1620 Discriminator Loss: 0.7787... Generator Loss: 2.1413
# Epoch 1/1... Step 1630 Discriminator Loss: 0.6308... Generator Loss: 2.9285
# Epoch 1/1... Step 1640 Discriminator Loss: 0.8578... Generator Loss: 1.3278
# Epoch 1/1... Step 1650 Discriminator Loss: 1.1168... Generator Loss: 2.2248
# Epoch 1/1... Step 1660 Discriminator Loss: 0.7415... Generator Loss: 1.7659
# Epoch 1/1... Step 1670 Discriminator Loss: 0.7471... Generator Loss: 2.2561
# Epoch 1/1... Step 1680 Discriminator Loss: 0.6661... Generator Loss: 2.3658
# Epoch 1/1... Step 1690 Discriminator Loss: 0.5521... Generator Loss: 2.3552
# Epoch 1/1... Step 1700 Discriminator Loss: 0.9249... Generator Loss: 4.3865
# Epoch 1/1... Step 1710 Discriminator Loss: 0.7478... Generator Loss: 1.7511
# Epoch 1/1... Step 1720 Discriminator Loss: 0.6164... Generator Loss: 1.9524
# Epoch 1/1... Step 1730 Discriminator Loss: 0.6679... Generator Loss: 2.5818
# Epoch 1/1... Step 1740 Discriminator Loss: 0.6929... Generator Loss: 1.9290
# Epoch 1/1... Step 1750 Discriminator Loss: 0.5964... Generator Loss: 1.8514
# Epoch 1/1... Step 1760 Discriminator Loss: 0.6806... Generator Loss: 1.6052
# Epoch 1/1... Step 1770 Discriminator Loss: 0.6999... Generator Loss: 2.1400
# Epoch 1/1... Step 1780 Discriminator Loss: 0.7399... Generator Loss: 2.3512
# Epoch 1/1... Step 1790 Discriminator Loss: 0.6252... Generator Loss: 1.8070
# Epoch 1/1... Step 1800 Discriminator Loss: 0.6045... Generator Loss: 2.0861
# Epoch 1/1... Step 1810 Discriminator Loss: 0.5844... Generator Loss: 2.9612
# Epoch 1/1... Step 1820 Discriminator Loss: 0.6049... Generator Loss: 2.1602
# Epoch 1/1... Step 1830 Discriminator Loss: 0.8778... Generator Loss: 1.2108
# Epoch 1/1... Step 1840 Discriminator Loss: 0.6007... Generator Loss: 2.8199
# Epoch 1/1... Step 1850 Discriminator Loss: 0.5485... Generator Loss: 2.5906
# Epoch 1/1... Step 1860 Discriminator Loss: 0.8361... Generator Loss: 2.8033
# Epoch 1/1... Step 1870 Discriminator Loss: 0.5178... Generator Loss: 2.7398
# Epoch 1/1... Step 1880 Discriminator Loss: 0.9081... Generator Loss: 1.1963
# Epoch 1/1... Step 1890 Discriminator Loss: 0.7082... Generator Loss: 2.0368
# Epoch 1/1... Step 1900 Discriminator Loss: 0.5724... Generator Loss: 2.3275
# Epoch 1/1... Step 1910 Discriminator Loss: 0.6462... Generator Loss: 2.1146
# Epoch 1/1... Step 1920 Discriminator Loss: 0.5541... Generator Loss: 2.2520
# Epoch 1/1... Step 1930 Discriminator Loss: 0.6530... Generator Loss: 1.8291
# Epoch 1/1... Step 1940 Discriminator Loss: 0.5012... Generator Loss: 2.9912
# Epoch 1/1... Step 1950 Discriminator Loss: 0.7043... Generator Loss: 2.3594
# Epoch 1/1... Step 1960 Discriminator Loss: 0.9523... Generator Loss: 1.2062
# Epoch 1/1... Step 1970 Discriminator Loss: 0.7691... Generator Loss: 1.5295
# Epoch 1/1... Step 1980 Discriminator Loss: 0.6120... Generator Loss: 2.0492
# Epoch 1/1... Step 1990 Discriminator Loss: 0.6545... Generator Loss: 2.3460
# Epoch 1/1... Step 2000 Discriminator Loss: 0.6624... Generator Loss: 3.0417
# Epoch 1/1... Step 2010 Discriminator Loss: 0.6078... Generator Loss: 2.3587
# Epoch 1/1... Step 2020 Discriminator Loss: 0.6465... Generator Loss: 1.7888
# Epoch 1/1... Step 2030 Discriminator Loss: 0.7046... Generator Loss: 1.6253
# Epoch 1/1... Step 2040 Discriminator Loss: 0.8131... Generator Loss: 1.4947
# Epoch 1/1... Step 2050 Discriminator Loss: 0.5602... Generator Loss: 2.3352
# Epoch 1/1... Step 2060 Discriminator Loss: 0.6804... Generator Loss: 1.8846
# Epoch 1/1... Step 2070 Discriminator Loss: 0.7602... Generator Loss: 3.1386
# Epoch 1/1... Step 2080 Discriminator Loss: 0.6561... Generator Loss: 1.9849
# Epoch 1/1... Step 2090 Discriminator Loss: 0.7218... Generator Loss: 1.9982
# Epoch 1/1... Step 2100 Discriminator Loss: 0.7005... Generator Loss: 2.1046
# Epoch 1/1... Step 2110 Discriminator Loss: 0.6270... Generator Loss: 1.9984
# Epoch 1/1... Step 2120 Discriminator Loss: 0.8596... Generator Loss: 1.2686
# Epoch 1/1... Step 2130 Discriminator Loss: 0.7300... Generator Loss: 3.6513
# Epoch 1/1... Step 2140 Discriminator Loss: 0.6800... Generator Loss: 1.9866
# Epoch 1/1... Step 2150 Discriminator Loss: 0.6319... Generator Loss: 1.8223
# Epoch 1/1... Step 2160 Discriminator Loss: 0.8224... Generator Loss: 1.1726
# Epoch 1/1... Step 2170 Discriminator Loss: 0.6619... Generator Loss: 1.9022
# Epoch 1/1... Step 2180 Discriminator Loss: 0.6426... Generator Loss: 1.8818
# Epoch 1/1... Step 2190 Discriminator Loss: 0.6928... Generator Loss: 1.7354
# Epoch 1/1... Step 2200 Discriminator Loss: 0.6451... Generator Loss: 1.7529
# Epoch 1/1... Step 2210 Discriminator Loss: 0.6986... Generator Loss: 1.7391
# Epoch 1/1... Step 2220 Discriminator Loss: 0.5524... Generator Loss: 2.8622
# Epoch 1/1... Step 2230 Discriminator Loss: 1.2202... Generator Loss: 0.7852
# Epoch 1/1... Step 2240 Discriminator Loss: 0.6397... Generator Loss: 2.8418
# Epoch 1/1... Step 2250 Discriminator Loss: 0.9833... Generator Loss: 0.9943
# Epoch 1/1... Step 2260 Discriminator Loss: 0.7163... Generator Loss: 1.9395
# Epoch 1/1... Step 2270 Discriminator Loss: 0.8189... Generator Loss: 1.4374
# Epoch 1/1... Step 2280 Discriminator Loss: 1.1187... Generator Loss: 0.8739
# Epoch 1/1... Step 2290 Discriminator Loss: 1.0141... Generator Loss: 1.1502
# Epoch 1/1... Step 2300 Discriminator Loss: 0.6498... Generator Loss: 1.8344
# Epoch 1/1... Step 2310 Discriminator Loss: 0.7229... Generator Loss: 1.8993
# Epoch 1/1... Step 2320 Discriminator Loss: 0.6909... Generator Loss: 2.0243
# Epoch 1/1... Step 2330 Discriminator Loss: 1.0537... Generator Loss: 0.9925
# Epoch 1/1... Step 2340 Discriminator Loss: 0.6496... Generator Loss: 1.9559
# Epoch 1/1... Step 2350 Discriminator Loss: 0.8259... Generator Loss: 1.2968
# Epoch 1/1... Step 2360 Discriminator Loss: 0.8488... Generator Loss: 1.2746
# Epoch 1/1... Step 2370 Discriminator Loss: 0.6403... Generator Loss: 2.3918
# Epoch 1/1... Step 2380 Discriminator Loss: 0.6281... Generator Loss: 2.6544
# Epoch 1/1... Step 2390 Discriminator Loss: 0.7161... Generator Loss: 1.6132
# Epoch 1/1... Step 2400 Discriminator Loss: 0.6037... Generator Loss: 2.5974
# Epoch 1/1... Step 2410 Discriminator Loss: 0.6534... Generator Loss: 2.4843
# Epoch 1/1... Step 2420 Discriminator Loss: 0.7022... Generator Loss: 2.9032
# Epoch 1/1... Step 2430 Discriminator Loss: 0.6865... Generator Loss: 1.5841
# Epoch 1/1... Step 2440 Discriminator Loss: 0.7078... Generator Loss: 1.7205
# Epoch 1/1... Step 2450 Discriminator Loss: 0.5597... Generator Loss: 2.6473
# Epoch 1/1... Step 2460 Discriminator Loss: 0.8585... Generator Loss: 1.3484
# Epoch 1/1... Step 2470 Discriminator Loss: 0.8098... Generator Loss: 1.3159
# Epoch 1/1... Step 2480 Discriminator Loss: 0.6610... Generator Loss: 1.9511
# Epoch 1/1... Step 2490 Discriminator Loss: 0.8279... Generator Loss: 1.4402
# Epoch 1/1... Step 2500 Discriminator Loss: 0.7293... Generator Loss: 1.9432
# Epoch 1/1... Step 2510 Discriminator Loss: 0.6007... Generator Loss: 2.9385
# Epoch 1/1... Step 2520 Discriminator Loss: 0.6429... Generator Loss: 1.8857
# Epoch 1/1... Step 2530 Discriminator Loss: 0.7376... Generator Loss: 3.0298
# Epoch 1/1... Step 2540 Discriminator Loss: 0.7920... Generator Loss: 1.5302
# Epoch 1/1... Step 2550 Discriminator Loss: 1.0166... Generator Loss: 1.0323
# Epoch 1/1... Step 2560 Discriminator Loss: 0.7911... Generator Loss: 1.7699
# Epoch 1/1... Step 2570 Discriminator Loss: 0.6985... Generator Loss: 2.9602
# Epoch 1/1... Step 2580 Discriminator Loss: 0.6398... Generator Loss: 2.7291
# Epoch 1/1... Step 2590 Discriminator Loss: 0.8647... Generator Loss: 1.2601
# Epoch 1/1... Step 2600 Discriminator Loss: 0.7334... Generator Loss: 1.5827
# Epoch 1/1... Step 2610 Discriminator Loss: 0.7214... Generator Loss: 2.4152
# Epoch 1/1... Step 2620 Discriminator Loss: 0.7515... Generator Loss: 2.2821
# Epoch 1/1... Step 2630 Discriminator Loss: 0.7782... Generator Loss: 1.7776
# Epoch 1/1... Step 2640 Discriminator Loss: 0.7471... Generator Loss: 2.6738
# Epoch 1/1... Step 2650 Discriminator Loss: 0.6097... Generator Loss: 2.6290
# Epoch 1/1... Step 2660 Discriminator Loss: 0.6659... Generator Loss: 1.8510
# Epoch 1/1... Step 2670 Discriminator Loss: 0.7452... Generator Loss: 1.5672
# Epoch 1/1... Step 2680 Discriminator Loss: 0.7806... Generator Loss: 1.5002
# Epoch 1/1... Step 2690 Discriminator Loss: 0.8315... Generator Loss: 1.4562
# Epoch 1/1... Step 2700 Discriminator Loss: 0.8778... Generator Loss: 1.1411
# Epoch 1/1... Step 2710 Discriminator Loss: 0.8055... Generator Loss: 2.2042
# Epoch 1/1... Step 2720 Discriminator Loss: 0.7098... Generator Loss: 1.8869
# Epoch 1/1... Step 2730 Discriminator Loss: 0.8627... Generator Loss: 1.1992
# Epoch 1/1... Step 2740 Discriminator Loss: 0.8074... Generator Loss: 1.2967
# Epoch 1/1... Step 2750 Discriminator Loss: 0.7956... Generator Loss: 1.2792
# Epoch 1/1... Step 2760 Discriminator Loss: 0.9381... Generator Loss: 1.1027
# Epoch 1/1... Step 2770 Discriminator Loss: 0.9879... Generator Loss: 2.6781
# Epoch 1/1... Step 2780 Discriminator Loss: 0.8775... Generator Loss: 1.2254
# Epoch 1/1... Step 2790 Discriminator Loss: 0.7446... Generator Loss: 2.6180
# Epoch 1/1... Step 2800 Discriminator Loss: 0.6682... Generator Loss: 1.7580
# Epoch 1/1... Step 2810 Discriminator Loss: 0.7383... Generator Loss: 1.5503
# Epoch 1/1... Step 2820 Discriminator Loss: 0.8053... Generator Loss: 1.2249
# Epoch 1/1... Step 2830 Discriminator Loss: 0.6627... Generator Loss: 1.8233
# Epoch 1/1... Step 2840 Discriminator Loss: 0.7190... Generator Loss: 1.4546
# Epoch 1/1... Step 2850 Discriminator Loss: 0.7784... Generator Loss: 2.5996
# Epoch 1/1... Step 2860 Discriminator Loss: 0.6771... Generator Loss: 1.7077
# Epoch 1/1... Step 2870 Discriminator Loss: 1.1539... Generator Loss: 0.7342
# Epoch 1/1... Step 2880 Discriminator Loss: 0.7054... Generator Loss: 1.7694
# Epoch 1/1... Step 2890 Discriminator Loss: 0.7924... Generator Loss: 1.2948
# Epoch 1/1... Step 2900 Discriminator Loss: 0.7088... Generator Loss: 1.4716
# Epoch 1/1... Step 2910 Discriminator Loss: 0.6848... Generator Loss: 2.2025
# Epoch 1/1... Step 2920 Discriminator Loss: 0.8320... Generator Loss: 1.2737
# Epoch 1/1... Step 2930 Discriminator Loss: 0.7946... Generator Loss: 1.4476
# Epoch 1/1... Step 2940 Discriminator Loss: 0.6279... Generator Loss: 2.0684
# Epoch 1/1... Step 2950 Discriminator Loss: 0.6082... Generator Loss: 2.1174
# Epoch 1/1... Step 2960 Discriminator Loss: 1.2016... Generator Loss: 3.2278
# Epoch 1/1... Step 2970 Discriminator Loss: 0.7835... Generator Loss: 1.4532
# Epoch 1/1... Step 2980 Discriminator Loss: 0.8829... Generator Loss: 1.4863
# Epoch 1/1... Step 2990 Discriminator Loss: 0.7041... Generator Loss: 2.8258
# Epoch 1/1... Step 3000 Discriminator Loss: 1.1661... Generator Loss: 0.7459
# Epoch 1/1... Step 3010 Discriminator Loss: 0.7173... Generator Loss: 2.4158
# Epoch 1/1... Step 3020 Discriminator Loss: 0.7056... Generator Loss: 2.1028
# Epoch 1/1... Step 3030 Discriminator Loss: 0.6381... Generator Loss: 2.0174
# Epoch 1/1... Step 3040 Discriminator Loss: 0.8430... Generator Loss: 1.3051
# Epoch 1/1... Step 3050 Discriminator Loss: 0.6866... Generator Loss: 1.6719
# Epoch 1/1... Step 3060 Discriminator Loss: 0.7943... Generator Loss: 1.4331
# Epoch 1/1... Step 3070 Discriminator Loss: 0.7783... Generator Loss: 1.4532
# Epoch 1/1... Step 3080 Discriminator Loss: 0.6524... Generator Loss: 1.6255
# Epoch 1/1... Step 3090 Discriminator Loss: 0.9776... Generator Loss: 1.0842
# Epoch 1/1... Step 3100 Discriminator Loss: 0.7649... Generator Loss: 1.8288
# Epoch 1/1... Step 3110 Discriminator Loss: 0.7972... Generator Loss: 1.4430
# Epoch 1/1... Step 3120 Discriminator Loss: 0.9166... Generator Loss: 1.0388
# Epoch 1/1... Step 3130 Discriminator Loss: 0.7695... Generator Loss: 1.9609
# Epoch 1/1... Step 3140 Discriminator Loss: 0.8776... Generator Loss: 1.3832
# Epoch 1/1... Step 3150 Discriminator Loss: 0.8173... Generator Loss: 1.3192
# Epoch 1/1... Step 3160 Discriminator Loss: 0.9267... Generator Loss: 1.0900
# Epoch 1/1... Step 3170 Discriminator Loss: 0.9243... Generator Loss: 1.0890
# Epoch 1/1... Step 3180 Discriminator Loss: 0.8722... Generator Loss: 2.4725
# Epoch 1/1... Step 3190 Discriminator Loss: 0.6507... Generator Loss: 1.7949
# Epoch 1/1... Step 3200 Discriminator Loss: 0.9310... Generator Loss: 1.1958
# Epoch 1/1... Step 3210 Discriminator Loss: 0.7191... Generator Loss: 1.6385
# Epoch 1/1... Step 3220 Discriminator Loss: 0.7339... Generator Loss: 1.8872
# Epoch 1/1... Step 3230 Discriminator Loss: 0.6752... Generator Loss: 1.8671
# Epoch 1/1... Step 3240 Discriminator Loss: 0.6452... Generator Loss: 1.9229
# Epoch 1/1... Step 3250 Discriminator Loss: 0.8685... Generator Loss: 3.4343
# Epoch 1/1... Step 3260 Discriminator Loss: 0.9381... Generator Loss: 1.0594
# Epoch 1/1... Step 3270 Discriminator Loss: 0.7010... Generator Loss: 1.6569
# Epoch 1/1... Step 3280 Discriminator Loss: 0.8769... Generator Loss: 1.1525
# Epoch 1/1... Step 3290 Discriminator Loss: 0.7675... Generator Loss: 1.3947
# Epoch 1/1... Step 3300 Discriminator Loss: 0.6953... Generator Loss: 1.7227
# Epoch 1/1... Step 3310 Discriminator Loss: 0.6779... Generator Loss: 1.8075
# Epoch 1/1... Step 3320 Discriminator Loss: 0.8144... Generator Loss: 2.0465
# Epoch 1/1... Step 3330 Discriminator Loss: 0.6266... Generator Loss: 1.8389
# Epoch 1/1... Step 3340 Discriminator Loss: 0.7467... Generator Loss: 1.4890
# Epoch 1/1... Step 3350 Discriminator Loss: 0.7416... Generator Loss: 1.7389
# Epoch 1/1... Step 3360 Discriminator Loss: 0.5552... Generator Loss: 2.2382
# Epoch 1/1... Step 3370 Discriminator Loss: 0.7606... Generator Loss: 1.4423
# Epoch 1/1... Step 3380 Discriminator Loss: 0.6303... Generator Loss: 2.2943
# Epoch 1/1... Step 3390 Discriminator Loss: 0.6408... Generator Loss: 1.8978
# Epoch 1/1... Step 3400 Discriminator Loss: 0.7835... Generator Loss: 1.4072
# Epoch 1/1... Step 3410 Discriminator Loss: 0.6141... Generator Loss: 1.8779
# Epoch 1/1... Step 3420 Discriminator Loss: 0.6418... Generator Loss: 2.6412
# Epoch 1/1... Step 3430 Discriminator Loss: 0.6069... Generator Loss: 2.3486
# Epoch 1/1... Step 3440 Discriminator Loss: 0.6364... Generator Loss: 1.9142
# Epoch 1/1... Step 3450 Discriminator Loss: 1.0712... Generator Loss: 0.9841
# Epoch 1/1... Step 3460 Discriminator Loss: 0.9126... Generator Loss: 1.5425
# Epoch 1/1... Step 3470 Discriminator Loss: 0.7545... Generator Loss: 1.5769
# Epoch 1/1... Step 3480 Discriminator Loss: 0.8917... Generator Loss: 1.1957
# Epoch 1/1... Step 3490 Discriminator Loss: 0.6990... Generator Loss: 1.7952
# Epoch 1/1... Step 3500 Discriminator Loss: 0.7827... Generator Loss: 1.4859
# Epoch 1/1... Step 3510 Discriminator Loss: 0.7154... Generator Loss: 2.2945
# Epoch 1/1... Step 3520 Discriminator Loss: 0.8005... Generator Loss: 1.6754
# Epoch 1/1... Step 3530 Discriminator Loss: 0.8045... Generator Loss: 1.5294
# Epoch 1/1... Step 3540 Discriminator Loss: 0.9296... Generator Loss: 2.0684
# Epoch 1/1... Step 3550 Discriminator Loss: 0.7279... Generator Loss: 1.6878
# Epoch 1/1... Step 3560 Discriminator Loss: 0.8410... Generator Loss: 1.3068
# Epoch 1/1... Step 3570 Discriminator Loss: 0.7980... Generator Loss: 1.7054
# Epoch 1/1... Step 3580 Discriminator Loss: 0.8688... Generator Loss: 2.1593
# Epoch 1/1... Step 3590 Discriminator Loss: 0.7223... Generator Loss: 1.6321
# Epoch 1/1... Step 3600 Discriminator Loss: 0.6163... Generator Loss: 2.0287
# Epoch 1/1... Step 3610 Discriminator Loss: 1.0757... Generator Loss: 0.9926
# Epoch 1/1... Step 3620 Discriminator Loss: 0.9892... Generator Loss: 0.9731
# Epoch 1/1... Step 3630 Discriminator Loss: 0.8934... Generator Loss: 1.2568
# Epoch 1/1... Step 3640 Discriminator Loss: 0.9114... Generator Loss: 1.8027
# Epoch 1/1... Step 3650 Discriminator Loss: 0.7765... Generator Loss: 2.1694
# Epoch 1/1... Step 3660 Discriminator Loss: 0.6619... Generator Loss: 2.3560
# Epoch 1/1... Step 3670 Discriminator Loss: 0.7438... Generator Loss: 1.6750
# Epoch 1/1... Step 3680 Discriminator Loss: 0.7683... Generator Loss: 1.5490
# Epoch 1/1... Step 3690 Discriminator Loss: 0.7296... Generator Loss: 1.6550
# Epoch 1/1... Step 3700 Discriminator Loss: 0.7568... Generator Loss: 2.1324
# Epoch 1/1... Step 3710 Discriminator Loss: 0.7577... Generator Loss: 1.6441
# Epoch 1/1... Step 3720 Discriminator Loss: 0.8583... Generator Loss: 1.3128
# Epoch 1/1... Step 3730 Discriminator Loss: 0.7020... Generator Loss: 1.9264
# Epoch 1/1... Step 3740 Discriminator Loss: 0.9320... Generator Loss: 0.9972
# Epoch 1/1... Step 3750 Discriminator Loss: 0.6535... Generator Loss: 2.2604
# Epoch 1/1... Step 3760 Discriminator Loss: 0.9617... Generator Loss: 1.1185
# Epoch 1/1... Step 3770 Discriminator Loss: 0.9410... Generator Loss: 1.1047
# Epoch 1/1... Step 3780 Discriminator Loss: 0.7922... Generator Loss: 1.3530
# Epoch 1/1... Step 3790 Discriminator Loss: 0.8366... Generator Loss: 1.3228
# Epoch 1/1... Step 3800 Discriminator Loss: 0.6369... Generator Loss: 2.0861
# Epoch 1/1... Step 3810 Discriminator Loss: 0.7289... Generator Loss: 1.4515
# Epoch 1/1... Step 3820 Discriminator Loss: 0.6626... Generator Loss: 1.6163
# Epoch 1/1... Step 3830 Discriminator Loss: 0.6098... Generator Loss: 1.9740
# Epoch 1/1... Step 3840 Discriminator Loss: 0.7870... Generator Loss: 1.3423
# Epoch 1/1... Step 3850 Discriminator Loss: 0.7867... Generator Loss: 2.2921
# Epoch 1/1... Step 3860 Discriminator Loss: 0.6767... Generator Loss: 1.7901
# Epoch 1/1... Step 3870 Discriminator Loss: 0.8585... Generator Loss: 3.0558
# Epoch 1/1... Step 3880 Discriminator Loss: 0.9248... Generator Loss: 1.5979
# Epoch 1/1... Step 3890 Discriminator Loss: 0.6669... Generator Loss: 2.1901
# Epoch 1/1... Step 3900 Discriminator Loss: 0.7088... Generator Loss: 1.4775
# Epoch 1/1... Step 3910 Discriminator Loss: 0.9163... Generator Loss: 1.3632
# Epoch 1/1... Step 3920 Discriminator Loss: 0.8755... Generator Loss: 1.3923
# Epoch 1/1... Step 3930 Discriminator Loss: 0.7634... Generator Loss: 1.6452
# Epoch 1/1... Step 3940 Discriminator Loss: 0.7562... Generator Loss: 1.9123
# Epoch 1/1... Step 3950 Discriminator Loss: 0.7260... Generator Loss: 1.4689
# Epoch 1/1... Step 3960 Discriminator Loss: 0.7057... Generator Loss: 2.1647
# Epoch 1/1... Step 3970 Discriminator Loss: 0.6307... Generator Loss: 2.0311
# Epoch 1/1... Step 3980 Discriminator Loss: 0.6841... Generator Loss: 1.7156
# Epoch 1/1... Step 3990 Discriminator Loss: 1.1937... Generator Loss: 0.9276
# Epoch 1/1... Step 4000 Discriminator Loss: 0.8655... Generator Loss: 1.4221
# Epoch 1/1... Step 4010 Discriminator Loss: 0.7598... Generator Loss: 1.5436
# Epoch 1/1... Step 4020 Discriminator Loss: 0.7260... Generator Loss: 1.8109
# Epoch 1/1... Step 4030 Discriminator Loss: 0.8588... Generator Loss: 1.4239
# Epoch 1/1... Step 4040 Discriminator Loss: 0.8915... Generator Loss: 1.1541
# Epoch 1/1... Step 4050 Discriminator Loss: 0.8192... Generator Loss: 1.2760
# Epoch 1/1... Step 4060 Discriminator Loss: 0.6684... Generator Loss: 1.9455
# Epoch 1/1... Step 4070 Discriminator Loss: 0.7360... Generator Loss: 2.1701
# Epoch 1/1... Step 4080 Discriminator Loss: 0.5786... Generator Loss: 1.9806
# Epoch 1/1... Step 4090 Discriminator Loss: 0.7219... Generator Loss: 1.8396
# Epoch 1/1... Step 4100 Discriminator Loss: 0.7050... Generator Loss: 1.6658
# Epoch 1/1... Step 4110 Discriminator Loss: 0.8108... Generator Loss: 2.1661
# Epoch 1/1... Step 4120 Discriminator Loss: 0.9384... Generator Loss: 1.1904
# Epoch 1/1... Step 4130 Discriminator Loss: 0.7611... Generator Loss: 2.7167
# Epoch 1/1... Step 4140 Discriminator Loss: 0.8181... Generator Loss: 1.3638
# Epoch 1/1... Step 4150 Discriminator Loss: 0.9036... Generator Loss: 1.2958
# Epoch 1/1... Step 4160 Discriminator Loss: 0.9962... Generator Loss: 2.8678
# Epoch 1/1... Step 4170 Discriminator Loss: 0.8833... Generator Loss: 1.3861
# Epoch 1/1... Step 4180 Discriminator Loss: 1.0830... Generator Loss: 0.8932
# Epoch 1/1... Step 4190 Discriminator Loss: 0.7405... Generator Loss: 1.8863
# Epoch 1/1... Step 4200 Discriminator Loss: 1.1616... Generator Loss: 0.8415
# Epoch 1/1... Step 4210 Discriminator Loss: 0.6889... Generator Loss: 1.6158
# Epoch 1/1... Step 4220 Discriminator Loss: 0.7273... Generator Loss: 1.5911
# Epoch 1/1... Step 4230 Discriminator Loss: 0.7668... Generator Loss: 1.7180
# Epoch 1/1... Step 4240 Discriminator Loss: 0.7098... Generator Loss: 1.9774
# Epoch 1/1... Step 4250 Discriminator Loss: 1.0879... Generator Loss: 0.8599
# Epoch 1/1... Step 4260 Discriminator Loss: 0.7877... Generator Loss: 1.8713
# Epoch 1/1... Step 4270 Discriminator Loss: 0.9984... Generator Loss: 0.9433
# Epoch 1/1... Step 4280 Discriminator Loss: 0.5500... Generator Loss: 2.6913
# Epoch 1/1... Step 4290 Discriminator Loss: 0.7907... Generator Loss: 1.5764
# Epoch 1/1... Step 4300 Discriminator Loss: 0.8640... Generator Loss: 1.1476
# Epoch 1/1... Step 4310 Discriminator Loss: 0.7867... Generator Loss: 1.6237
# Epoch 1/1... Step 4320 Discriminator Loss: 0.8512... Generator Loss: 1.3956
# Epoch 1/1... Step 4330 Discriminator Loss: 0.7175... Generator Loss: 1.6552
# Epoch 1/1... Step 4340 Discriminator Loss: 0.7308... Generator Loss: 1.6870
# Epoch 1/1... Step 4350 Discriminator Loss: 0.7219... Generator Loss: 1.6877
# Epoch 1/1... Step 4360 Discriminator Loss: 0.9163... Generator Loss: 1.2263
# Epoch 1/1... Step 4370 Discriminator Loss: 0.9785... Generator Loss: 1.0309
# Epoch 1/1... Step 4380 Discriminator Loss: 0.8902... Generator Loss: 1.1662
# Epoch 1/1... Step 4390 Discriminator Loss: 1.1099... Generator Loss: 0.9031
# Epoch 1/1... Step 4400 Discriminator Loss: 0.8926... Generator Loss: 1.1838
# Epoch 1/1... Step 4410 Discriminator Loss: 1.1162... Generator Loss: 0.8590
# Epoch 1/1... Step 4420 Discriminator Loss: 0.7565... Generator Loss: 2.7717
# Epoch 1/1... Step 4430 Discriminator Loss: 0.6371... Generator Loss: 2.2234
# Epoch 1/1... Step 4440 Discriminator Loss: 0.7325... Generator Loss: 1.6041
# Epoch 1/1... Step 4450 Discriminator Loss: 0.7269... Generator Loss: 1.6120
# Epoch 1/1... Step 4460 Discriminator Loss: 0.7463... Generator Loss: 1.8704
# Epoch 1/1... Step 4470 Discriminator Loss: 0.8816... Generator Loss: 1.3670
# Epoch 1/1... Step 4480 Discriminator Loss: 0.8234... Generator Loss: 1.5394
# Epoch 1/1... Step 4490 Discriminator Loss: 0.9501... Generator Loss: 1.7756
# Epoch 1/1... Step 4500 Discriminator Loss: 0.8817... Generator Loss: 1.1564
# Epoch 1/1... Step 4510 Discriminator Loss: 0.8370... Generator Loss: 1.8308
# Epoch 1/1... Step 4520 Discriminator Loss: 0.8396... Generator Loss: 1.4373
# Epoch 1/1... Step 4530 Discriminator Loss: 0.7686... Generator Loss: 1.7075
# Epoch 1/1... Step 4540 Discriminator Loss: 0.7748... Generator Loss: 1.4345
# Epoch 1/1... Step 4550 Discriminator Loss: 0.7423... Generator Loss: 1.5289
# Epoch 1/1... Step 4560 Discriminator Loss: 0.8615... Generator Loss: 1.3163
# Epoch 1/1... Step 4570 Discriminator Loss: 0.7406... Generator Loss: 2.2472
# Epoch 1/1... Step 4580 Discriminator Loss: 0.8368... Generator Loss: 1.3121
# Epoch 1/1... Step 4590 Discriminator Loss: 0.7063... Generator Loss: 1.5864
# Epoch 1/1... Step 4600 Discriminator Loss: 0.8228... Generator Loss: 1.7057
# Epoch 1/1... Step 4610 Discriminator Loss: 0.8652... Generator Loss: 1.1544
# Epoch 1/1... Step 4620 Discriminator Loss: 0.8981... Generator Loss: 1.5621
# Epoch 1/1... Step 4630 Discriminator Loss: 0.5931... Generator Loss: 2.1815
# Epoch 1/1... Step 4640 Discriminator Loss: 0.6949... Generator Loss: 1.8561
# Epoch 1/1... Step 4650 Discriminator Loss: 0.8808... Generator Loss: 1.3670
# Epoch 1/1... Step 4660 Discriminator Loss: 0.7631... Generator Loss: 2.1109
# Epoch 1/1... Step 4670 Discriminator Loss: 0.7424... Generator Loss: 1.4772
# Epoch 1/1... Step 4680 Discriminator Loss: 0.7644... Generator Loss: 1.8945
# Epoch 1/1... Step 4690 Discriminator Loss: 0.6722... Generator Loss: 1.6699
# Epoch 1/1... Step 4700 Discriminator Loss: 0.6264... Generator Loss: 2.1770
# Epoch 1/1... Step 4710 Discriminator Loss: 0.8135... Generator Loss: 1.5085
# Epoch 1/1... Step 4720 Discriminator Loss: 0.8102... Generator Loss: 1.3808
# Epoch 1/1... Step 4730 Discriminator Loss: 0.7781... Generator Loss: 1.5746
# Epoch 1/1... Step 4740 Discriminator Loss: 0.7621... Generator Loss: 1.4907
# Epoch 1/1... Step 4750 Discriminator Loss: 0.6622... Generator Loss: 1.7566
# Epoch 1/1... Step 4760 Discriminator Loss: 0.7685... Generator Loss: 1.5429
# Epoch 1/1... Step 4770 Discriminator Loss: 0.7089... Generator Loss: 1.8539
# Epoch 1/1... Step 4780 Discriminator Loss: 0.7948... Generator Loss: 1.2759
# Epoch 1/1... Step 4790 Discriminator Loss: 0.7950... Generator Loss: 1.2551
# Epoch 1/1... Step 4800 Discriminator Loss: 0.6286... Generator Loss: 1.7644
# Epoch 1/1... Step 4810 Discriminator Loss: 0.8862... Generator Loss: 1.1802
# Epoch 1/1... Step 4820 Discriminator Loss: 0.7700... Generator Loss: 2.5041
# Epoch 1/1... Step 4830 Discriminator Loss: 0.8464... Generator Loss: 1.2956
# Epoch 1/1... Step 4840 Discriminator Loss: 0.9048... Generator Loss: 1.0653
# Epoch 1/1... Step 4850 Discriminator Loss: 0.6538... Generator Loss: 1.8555
# Epoch 1/1... Step 4860 Discriminator Loss: 0.6974... Generator Loss: 2.1686
# Epoch 1/1... Step 4870 Discriminator Loss: 0.9516... Generator Loss: 1.1154
# Epoch 1/1... Step 4880 Discriminator Loss: 0.7343... Generator Loss: 1.7070
# Epoch 1/1... Step 4890 Discriminator Loss: 0.7548... Generator Loss: 1.6067
# Epoch 1/1... Step 4900 Discriminator Loss: 0.8741... Generator Loss: 1.2208
# Epoch 1/1... Step 4910 Discriminator Loss: 0.8226... Generator Loss: 1.3040
# Epoch 1/1... Step 4920 Discriminator Loss: 0.6764... Generator Loss: 1.8317
# Epoch 1/1... Step 4930 Discriminator Loss: 0.7166... Generator Loss: 1.7160
# Epoch 1/1... Step 4940 Discriminator Loss: 0.7628... Generator Loss: 1.9067
# Epoch 1/1... Step 4950 Discriminator Loss: 0.6091... Generator Loss: 1.9888
# Epoch 1/1... Step 4960 Discriminator Loss: 0.9085... Generator Loss: 1.0708
# Epoch 1/1... Step 4970 Discriminator Loss: 1.0036... Generator Loss: 1.1994
# Epoch 1/1... Step 4980 Discriminator Loss: 1.0217... Generator Loss: 0.8286
# Epoch 1/1... Step 4990 Discriminator Loss: 0.9834... Generator Loss: 0.9767
# Epoch 1/1... Step 5000 Discriminator Loss: 0.7142... Generator Loss: 1.8646
# Epoch 1/1... Step 5010 Discriminator Loss: 0.9027... Generator Loss: 1.2113
# Epoch 1/1... Step 5020 Discriminator Loss: 1.3228... Generator Loss: 0.6568
# Epoch 1/1... Step 5030 Discriminator Loss: 0.6296... Generator Loss: 1.8514
# Epoch 1/1... Step 5040 Discriminator Loss: 0.9099... Generator Loss: 1.4133
# Epoch 1/1... Step 5050 Discriminator Loss: 0.7502... Generator Loss: 1.5827
# Epoch 1/1... Step 5060 Discriminator Loss: 0.7969... Generator Loss: 1.3501
# Epoch 1/1... Step 5070 Discriminator Loss: 0.6652... Generator Loss: 1.8047
# Epoch 1/1... Step 5080 Discriminator Loss: 0.8351... Generator Loss: 1.3810
# Epoch 1/1... Step 5090 Discriminator Loss: 1.0187... Generator Loss: 0.9732
# Epoch 1/1... Step 5100 Discriminator Loss: 0.8009... Generator Loss: 1.3223
# Epoch 1/1... Step 5110 Discriminator Loss: 1.2416... Generator Loss: 0.7450
# Epoch 1/1... Step 5120 Discriminator Loss: 0.6488... Generator Loss: 1.9945
# Epoch 1/1... Step 5130 Discriminator Loss: 1.0707... Generator Loss: 0.8576
# Epoch 1/1... Step 5140 Discriminator Loss: 0.9050... Generator Loss: 1.3742
# Epoch 1/1... Step 5150 Discriminator Loss: 0.8937... Generator Loss: 1.2348
# Epoch 1/1... Step 5160 Discriminator Loss: 0.6466... Generator Loss: 1.8221
# Epoch 1/1... Step 5170 Discriminator Loss: 0.7272... Generator Loss: 1.6389
# Epoch 1/1... Step 5180 Discriminator Loss: 0.6349... Generator Loss: 1.9508
# Epoch 1/1... Step 5190 Discriminator Loss: 0.7544... Generator Loss: 1.4420
# Epoch 1/1... Step 5200 Discriminator Loss: 0.7107... Generator Loss: 1.3799
# Epoch 1/1... Step 5210 Discriminator Loss: 0.7490... Generator Loss: 1.6911
# Epoch 1/1... Step 5220 Discriminator Loss: 0.8641... Generator Loss: 1.2245
# Epoch 1/1... Step 5230 Discriminator Loss: 1.1906... Generator Loss: 0.7328
# Epoch 1/1... Step 5240 Discriminator Loss: 1.0315... Generator Loss: 2.8510
# Epoch 1/1... Step 5250 Discriminator Loss: 0.8283... Generator Loss: 1.4822
# Epoch 1/1... Step 5260 Discriminator Loss: 0.8898... Generator Loss: 1.0901
# Epoch 1/1... Step 5270 Discriminator Loss: 0.6737... Generator Loss: 1.6377
# Epoch 1/1... Step 5280 Discriminator Loss: 0.8717... Generator Loss: 1.3363
# Epoch 1/1... Step 5290 Discriminator Loss: 0.7194... Generator Loss: 2.2584
# Epoch 1/1... Step 5300 Discriminator Loss: 0.6917... Generator Loss: 1.5299
# Epoch 1/1... Step 5310 Discriminator Loss: 0.9157... Generator Loss: 1.5930
# Epoch 1/1... Step 5320 Discriminator Loss: 0.7581... Generator Loss: 1.7009
# Epoch 1/1... Step 5330 Discriminator Loss: 0.7837... Generator Loss: 1.6181
# Epoch 1/1... Step 5340 Discriminator Loss: 0.9011... Generator Loss: 1.1716
# Epoch 1/1... Step 5350 Discriminator Loss: 0.8942... Generator Loss: 1.1347
# Epoch 1/1... Step 5360 Discriminator Loss: 0.9673... Generator Loss: 1.0083
# Epoch 1/1... Step 5370 Discriminator Loss: 0.7502... Generator Loss: 1.8476
# Epoch 1/1... Step 5380 Discriminator Loss: 0.6889... Generator Loss: 2.2358
# Epoch 1/1... Step 5390 Discriminator Loss: 0.7564... Generator Loss: 1.7773
# Epoch 1/1... Step 5400 Discriminator Loss: 0.6695... Generator Loss: 1.7651
# Epoch 1/1... Step 5410 Discriminator Loss: 0.7129... Generator Loss: 1.7607
# Epoch 1/1... Step 5420 Discriminator Loss: 0.6624... Generator Loss: 1.9819
# Epoch 1/1... Step 5430 Discriminator Loss: 0.6405... Generator Loss: 1.7380
# Epoch 1/1... Step 5440 Discriminator Loss: 0.6953... Generator Loss: 1.5893
# Epoch 1/1... Step 5450 Discriminator Loss: 0.5150... Generator Loss: 2.4638
# Epoch 1/1... Step 5460 Discriminator Loss: 1.5377... Generator Loss: 0.5886
# Epoch 1/1... Step 5470 Discriminator Loss: 0.8495... Generator Loss: 1.2849
# Epoch 1/1... Step 5480 Discriminator Loss: 0.7949... Generator Loss: 1.2582
# Epoch 1/1... Step 5490 Discriminator Loss: 0.8060... Generator Loss: 1.9742
# Epoch 1/1... Step 5500 Discriminator Loss: 0.8968... Generator Loss: 1.1420
# Epoch 1/1... Step 5510 Discriminator Loss: 0.8453... Generator Loss: 1.5715
# Epoch 1/1... Step 5520 Discriminator Loss: 0.8375... Generator Loss: 1.6428
# Epoch 1/1... Step 5530 Discriminator Loss: 0.8855... Generator Loss: 1.2859
# Epoch 1/1... Step 5540 Discriminator Loss: 0.7761... Generator Loss: 1.5172
# Epoch 1/1... Step 5550 Discriminator Loss: 0.6784... Generator Loss: 2.0252
# Epoch 1/1... Step 5560 Discriminator Loss: 0.6323... Generator Loss: 1.9228
# Epoch 1/1... Step 5570 Discriminator Loss: 0.7045... Generator Loss: 1.7389
# Epoch 1/1... Step 5580 Discriminator Loss: 0.8320... Generator Loss: 2.1329
# Epoch 1/1... Step 5590 Discriminator Loss: 0.8356... Generator Loss: 1.4909
# Epoch 1/1... Step 5600 Discriminator Loss: 0.6737... Generator Loss: 1.9661
# Epoch 1/1... Step 5610 Discriminator Loss: 0.9185... Generator Loss: 1.3423
# Epoch 1/1... Step 5620 Discriminator Loss: 0.9562... Generator Loss: 1.0438
# Epoch 1/1... Step 5630 Discriminator Loss: 0.7635... Generator Loss: 1.4251
# Epoch 1/1... Step 5640 Discriminator Loss: 0.9646... Generator Loss: 0.9278
# Epoch 1/1... Step 5650 Discriminator Loss: 0.7129... Generator Loss: 2.0401
# Epoch 1/1... Step 5660 Discriminator Loss: 0.7168... Generator Loss: 2.0140
# Epoch 1/1... Step 5670 Discriminator Loss: 0.7989... Generator Loss: 1.3824
# Epoch 1/1... Step 5680 Discriminator Loss: 0.7988... Generator Loss: 1.4338
# Epoch 1/1... Step 5690 Discriminator Loss: 0.7860... Generator Loss: 1.7074
# Epoch 1/1... Step 5700 Discriminator Loss: 0.6914... Generator Loss: 1.6593
# Epoch 1/1... Step 5710 Discriminator Loss: 0.7174... Generator Loss: 1.5699
# Epoch 1/1... Step 5720 Discriminator Loss: 0.7816... Generator Loss: 1.5591
# Epoch 1/1... Step 5730 Discriminator Loss: 0.9991... Generator Loss: 0.9297
# Epoch 1/1... Step 5740 Discriminator Loss: 0.7429... Generator Loss: 1.7434
# Epoch 1/1... Step 5750 Discriminator Loss: 0.8816... Generator Loss: 1.1548
# Epoch 1/1... Step 5760 Discriminator Loss: 0.9320... Generator Loss: 1.2663
# Epoch 1/1... Step 5770 Discriminator Loss: 0.8097... Generator Loss: 1.2610
# Epoch 1/1... Step 5780 Discriminator Loss: 0.7009... Generator Loss: 1.5261
# Epoch 1/1... Step 5790 Discriminator Loss: 0.7414... Generator Loss: 1.9287
# Epoch 1/1... Step 5800 Discriminator Loss: 0.9089... Generator Loss: 1.0623
# Epoch 1/1... Step 5810 Discriminator Loss: 0.8744... Generator Loss: 1.1558
# Epoch 1/1... Step 5820 Discriminator Loss: 0.7948... Generator Loss: 1.4185
# Epoch 1/1... Step 5830 Discriminator Loss: 0.7126... Generator Loss: 1.6545
# Epoch 1/1... Step 5840 Discriminator Loss: 0.6145... Generator Loss: 2.7353
# Epoch 1/1... Step 5850 Discriminator Loss: 0.9641... Generator Loss: 1.0613
# Epoch 1/1... Step 5860 Discriminator Loss: 1.2092... Generator Loss: 0.7130
# Epoch 1/1... Step 5870 Discriminator Loss: 0.8899... Generator Loss: 1.2128
# Epoch 1/1... Step 5880 Discriminator Loss: 0.7400... Generator Loss: 1.8088
# Epoch 1/1... Step 5890 Discriminator Loss: 1.0820... Generator Loss: 0.9698
# Epoch 1/1... Step 5900 Discriminator Loss: 0.7250... Generator Loss: 1.7749
# Epoch 1/1... Step 5910 Discriminator Loss: 0.7960... Generator Loss: 1.5027
# Epoch 1/1... Step 5920 Discriminator Loss: 0.6658... Generator Loss: 1.7718
# Epoch 1/1... Step 5930 Discriminator Loss: 0.6647... Generator Loss: 1.8622
# Epoch 1/1... Step 5940 Discriminator Loss: 1.0483... Generator Loss: 1.7665
# Epoch 1/1... Step 5950 Discriminator Loss: 0.9497... Generator Loss: 0.9865
# Epoch 1/1... Step 5960 Discriminator Loss: 0.9081... Generator Loss: 1.1939
# Epoch 1/1... Step 5970 Discriminator Loss: 0.7652... Generator Loss: 1.4054
# Epoch 1/1... Step 5980 Discriminator Loss: 0.8012... Generator Loss: 1.4213
# Epoch 1/1... Step 5990 Discriminator Loss: 1.1522... Generator Loss: 0.9981
# Epoch 1/1... Step 6000 Discriminator Loss: 0.9785... Generator Loss: 0.9640
# Epoch 1/1... Step 6010 Discriminator Loss: 0.9263... Generator Loss: 1.1430
# Epoch 1/1... Step 6020 Discriminator Loss: 0.6463... Generator Loss: 2.0136
# Epoch 1/1... Step 6030 Discriminator Loss: 0.8608... Generator Loss: 1.1367
# Epoch 1/1... Step 6040 Discriminator Loss: 0.8473... Generator Loss: 1.3246
# Epoch 1/1... Step 6050 Discriminator Loss: 0.8362... Generator Loss: 1.8130
# Epoch 1/1... Step 6060 Discriminator Loss: 0.7685... Generator Loss: 1.6359
# Epoch 1/1... Step 6070 Discriminator Loss: 0.8497... Generator Loss: 1.3753
# Epoch 1/1... Step 6080 Discriminator Loss: 0.7511... Generator Loss: 1.6619
# Epoch 1/1... Step 6090 Discriminator Loss: 1.1310... Generator Loss: 0.7966
# Epoch 1/1... Step 6100 Discriminator Loss: 0.7711... Generator Loss: 1.5425
# Epoch 1/1... Step 6110 Discriminator Loss: 0.9892... Generator Loss: 1.3757
# Epoch 1/1... Step 6120 Discriminator Loss: 0.9137... Generator Loss: 1.6313
# Epoch 1/1... Step 6130 Discriminator Loss: 0.7003... Generator Loss: 1.6651
# Epoch 1/1... Step 6140 Discriminator Loss: 0.9540... Generator Loss: 1.0672
# Epoch 1/1... Step 6150 Discriminator Loss: 0.8134... Generator Loss: 2.1526
# Epoch 1/1... Step 6160 Discriminator Loss: 0.8327... Generator Loss: 1.5985
# Epoch 1/1... Step 6170 Discriminator Loss: 0.9480... Generator Loss: 1.1728
# Epoch 1/1... Step 6180 Discriminator Loss: 0.6700... Generator Loss: 1.8340
# Epoch 1/1... Step 6190 Discriminator Loss: 0.7299... Generator Loss: 1.7326
# Epoch 1/1... Step 6200 Discriminator Loss: 0.9177... Generator Loss: 1.1282
# Epoch 1/1... Step 6210 Discriminator Loss: 0.7373... Generator Loss: 2.1935
# Epoch 1/1... Step 6220 Discriminator Loss: 0.7243... Generator Loss: 1.8634
# Epoch 1/1... Step 6230 Discriminator Loss: 0.8080... Generator Loss: 1.5174
# Epoch 1/1... Step 6240 Discriminator Loss: 0.7923... Generator Loss: 1.2099
# Epoch 1/1... Step 6250 Discriminator Loss: 0.8901... Generator Loss: 1.2503
# Epoch 1/1... Step 6260 Discriminator Loss: 0.7987... Generator Loss: 1.4650
# Epoch 1/1... Step 6270 Discriminator Loss: 0.8309... Generator Loss: 1.6751
# Epoch 1/1... Step 6280 Discriminator Loss: 0.7726... Generator Loss: 1.5853
# Epoch 1/1... Step 6290 Discriminator Loss: 1.0144... Generator Loss: 0.8602
# Epoch 1/1... Step 6300 Discriminator Loss: 1.0316... Generator Loss: 0.9997
# Epoch 1/1... Step 6310 Discriminator Loss: 0.8165... Generator Loss: 1.7498
# Epoch 1/1... Step 6320 Discriminator Loss: 0.8722... Generator Loss: 1.0341
# Epoch 1/1... Step 6330 Discriminator Loss: 0.6012... Generator Loss: 2.4520

# %% [markdown]
# ### Submitting This Project
# When submitting this project, make sure to run all the cells before saving the notebook. Save the notebook file as "dlnd_face_generation.ipynb" and save it as a HTML file under "File" -> "Download as". Include the "helper.py" and "problem_unittests.py" files in your submission.
